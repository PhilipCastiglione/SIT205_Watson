# %% [markdown]
# # SIT205 Thinking Systems and Cognition Science - Assignment 2
#
# ## Group: Philip Castiglione (217157862) and Warwick Smith (215239649)
#
# ## Topic 1: Text Analysis
#
# ## Project Code

# %% [markdown]
# We chose to analyse the recent events of Australian politics using text produced by members of the general public on Twitter.
#
# To do this, we collected approximately 6,000 tweets containing the hashtag #libspill using the Twitter API. We obtain these using the open source `python-twitter` [client library](https://github.com/bear/python-twitter).
#
# We then clean and filter these tweets to leave us with a set of 941 unique documents for textual analysis.
#
# We send these documents to the Watson Natural Language Understanding API.
#
# Finally, we complete a statistical analysis of the results.
#
# This notebook is separated into 4 parts:
#
# 1. [Part 1 - Document Collection](#Part-1---Document-Collection)
# 1. [Part 2 - Document Cleaning](#Part-2---Document-Cleaning)
# 1. [Part 3 - Watson NLU](#Part-3---Watson-NLU)
# 1. [Part 4 - Analysis of Watson Output](#Part-4---Analysis-of-Watson-Output)
#
# Notes:
# - Each part writes out results to a file, to allow us to work on sections independently, and to save on API calls
# - We ran the analysis at Mon 17 Sept 2018 and the number of tweets and documents were from this run. Running at a different point in time will lead to different data capture and results.

# %% [markdown]
# ### Setup

# %% [markdown]
# Load our dependencies:

# %%
# Standard library
import os
import pickle
import json
from collections import Counter
import statistics

# Additional libraries
import twitter                    # python-twitter API
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 import *
from dotenv import load_dotenv    # for management of twitter credentials

# %% [markdown]
# We use the `dotenv` library to load key-value pairs from a `.env` file into the os environment:

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# Utilise external environment to source our API authentication credentials:

# %%
TWITTER_CONSUMER_KEY = os.getenv("TWITTER_CONSUMER_KEY")
TWITTER_CONSUMER_SECRET = os.getenv("TWITTER_CONSUMER_SECRET")
TWITTER_ACCESS_TOKEN_KEY = os.getenv("TWITTER_ACCESS_TOKEN_KEY")
TWITTER_ACCESS_TOKEN_SECRET = os.getenv("TWITTER_ACCESS_TOKEN_SECRET")
WATSON_NLU_API_KEY = os.getenv("WATSON_NLU_API_KEY")

# WARNING: do not commit to git with any of these values printed to a cell's output

# %% [markdown]
# ## Part 1 - Document Collection

# %% [markdown]
# [Return to Contents](#Topic-1:-Text-Analysis)

# %% [markdown]
# Create python-twitter API instance:

# %%
api = twitter.Api(consumer_key=TWITTER_CONSUMER_KEY,
                  consumer_secret=TWITTER_CONSUMER_SECRET,
                  access_token_key=TWITTER_ACCESS_TOKEN_KEY,
                  access_token_secret=TWITTER_ACCESS_TOKEN_SECRET,
                  tweet_mode='extended')

# %% [markdown]
# Twitter search hashtag to find documents for analysis:

# %%
hashtag = "libspill"

# %% [markdown]
# We collect tweets in batches, up to a particular count, total_count:

# %%
def collect_tweets(api, hashtag, batch_max, total_count):
    tweets = []
    batch_max = str(batch_max)
    results = api.GetSearch(term=hashtag, result_type="recent", lang="en", 
                            count=batch_max, return_json=True)

    tweets += results['statuses']
    
    ids = [tweet['id'] for tweet in tweets]
    max_tweet_id = str(min(ids)-1)
    
    previous_tweet_count = 0
    while len(tweets) < total_count and len(tweets) > previous_tweet_count:
        previous_tweet_count = len(tweets)
        
        print("{} tweets collected for hashtag {}. Most recent tweeted at {}".format(
            len(tweets), hashtag, tweets[len(tweets)-1]['created_at']))
        
        results = api.GetSearch(term=hashtag, result_type="recent", lang="en", 
                                count=batch_max, return_json=True, max_id=max_tweet_id)
        tweets += results['statuses']
        ids = [tweet['id'] for tweet in tweets]
        max_tweet_id = str(min(ids)-1)
        
    print("{} tweets collected for hashtag {}. Most recent tweeted at {}".format(
            len(tweets), hashtag, tweets[len(tweets)-1]['created_at']))
    return tweets

# %% [markdown]
# To allow for tweet cleaning, and particularly filtering of re-tweets, we aim to collect 6,000 tweets relating to the #libspill hashtag:

# %%
tweet_collection = collect_tweets(api, hashtag, 100, 6000)
# Out:
# 100 tweets collected for hashtag libspill. Most recent tweeted at Mon Sep 17 05:59:07 +0000 2018
# 200 tweets collected for hashtag libspill. Most recent tweeted at Sun Sep 16 23:05:12 +0000 2018
# 300 tweets collected for hashtag libspill. Most recent tweeted at Sun Sep 16 08:46:30 +0000 2018
# 400 tweets collected for hashtag libspill. Most recent tweeted at Sun Sep 16 00:06:21 +0000 2018
# 500 tweets collected for hashtag libspill. Most recent tweeted at Sat Sep 15 22:57:07 +0000 2018
# 600 tweets collected for hashtag libspill. Most recent tweeted at Sat Sep 15 08:51:00 +0000 2018
# 700 tweets collected for hashtag libspill. Most recent tweeted at Sat Sep 15 01:24:29 +0000 2018
# 800 tweets collected for hashtag libspill. Most recent tweeted at Fri Sep 14 13:27:57 +0000 2018
# 900 tweets collected for hashtag libspill. Most recent tweeted at Fri Sep 14 07:47:36 +0000 2018
# 1000 tweets collected for hashtag libspill. Most recent tweeted at Fri Sep 14 04:19:05 +0000 2018
# 1100 tweets collected for hashtag libspill. Most recent tweeted at Fri Sep 14 02:44:54 +0000 2018
# 1200 tweets collected for hashtag libspill. Most recent tweeted at Fri Sep 14 01:08:42 +0000 2018
# 1300 tweets collected for hashtag libspill. Most recent tweeted at Thu Sep 13 22:08:58 +0000 2018
# 1400 tweets collected for hashtag libspill. Most recent tweeted at Thu Sep 13 20:18:51 +0000 2018
# 1500 tweets collected for hashtag libspill. Most recent tweeted at Thu Sep 13 13:50:57 +0000 2018
# 1583 tweets collected for hashtag libspill. Most recent tweeted at Thu Sep 13 10:54:01 +0000 2018
# 1683 tweets collected for hashtag libspill. Most recent tweeted at Thu Sep 13 08:05:47 +0000 2018
# 1783 tweets collected for hashtag libspill. Most recent tweeted at Thu Sep 13 06:52:24 +0000 2018
# 1883 tweets collected for hashtag libspill. Most recent tweeted at Thu Sep 13 05:27:27 +0000 2018
# 1983 tweets collected for hashtag libspill. Most recent tweeted at Thu Sep 13 04:30:59 +0000 2018
# 2083 tweets collected for hashtag libspill. Most recent tweeted at Thu Sep 13 03:00:19 +0000 2018
# 2183 tweets collected for hashtag libspill. Most recent tweeted at Thu Sep 13 01:24:21 +0000 2018
# 2283 tweets collected for hashtag libspill. Most recent tweeted at Wed Sep 12 23:34:33 +0000 2018
# 2383 tweets collected for hashtag libspill. Most recent tweeted at Wed Sep 12 21:42:06 +0000 2018
# 2483 tweets collected for hashtag libspill. Most recent tweeted at Wed Sep 12 15:37:48 +0000 2018
# 2583 tweets collected for hashtag libspill. Most recent tweeted at Wed Sep 12 12:23:37 +0000 2018
# 2683 tweets collected for hashtag libspill. Most recent tweeted at Wed Sep 12 10:04:18 +0000 2018
# 2783 tweets collected for hashtag libspill. Most recent tweeted at Wed Sep 12 07:58:29 +0000 2018
# 2883 tweets collected for hashtag libspill. Most recent tweeted at Wed Sep 12 06:14:29 +0000 2018
# 2983 tweets collected for hashtag libspill. Most recent tweeted at Wed Sep 12 04:42:39 +0000 2018
# 3083 tweets collected for hashtag libspill. Most recent tweeted at Wed Sep 12 03:40:28 +0000 2018
# 3183 tweets collected for hashtag libspill. Most recent tweeted at Wed Sep 12 02:56:04 +0000 2018
# 3283 tweets collected for hashtag libspill. Most recent tweeted at Wed Sep 12 00:54:13 +0000 2018
# 3383 tweets collected for hashtag libspill. Most recent tweeted at Tue Sep 11 22:26:15 +0000 2018
# 3483 tweets collected for hashtag libspill. Most recent tweeted at Tue Sep 11 14:37:16 +0000 2018
# 3583 tweets collected for hashtag libspill. Most recent tweeted at Tue Sep 11 10:37:20 +0000 2018
# 3683 tweets collected for hashtag libspill. Most recent tweeted at Tue Sep 11 08:26:52 +0000 2018
# 3783 tweets collected for hashtag libspill. Most recent tweeted at Tue Sep 11 06:10:00 +0000 2018
# 3883 tweets collected for hashtag libspill. Most recent tweeted at Tue Sep 11 04:36:11 +0000 2018
# 3983 tweets collected for hashtag libspill. Most recent tweeted at Tue Sep 11 03:43:34 +0000 2018
# 4083 tweets collected for hashtag libspill. Most recent tweeted at Mon Sep 10 22:45:35 +0000 2018
# 4183 tweets collected for hashtag libspill. Most recent tweeted at Mon Sep 10 14:38:39 +0000 2018
# 4283 tweets collected for hashtag libspill. Most recent tweeted at Mon Sep 10 11:21:47 +0000 2018
# 4383 tweets collected for hashtag libspill. Most recent tweeted at Mon Sep 10 08:27:23 +0000 2018
# 4483 tweets collected for hashtag libspill. Most recent tweeted at Mon Sep 10 06:55:23 +0000 2018
# 4583 tweets collected for hashtag libspill. Most recent tweeted at Mon Sep 10 05:47:20 +0000 2018
# 4683 tweets collected for hashtag libspill. Most recent tweeted at Mon Sep 10 04:51:46 +0000 2018
# 4783 tweets collected for hashtag libspill. Most recent tweeted at Mon Sep 10 03:56:28 +0000 2018
# 4878 tweets collected for hashtag libspill. Most recent tweeted at Mon Sep 10 03:00:07 +0000 2018
# 4978 tweets collected for hashtag libspill. Most recent tweeted at Mon Sep 10 01:57:18 +0000 2018
# 5078 tweets collected for hashtag libspill. Most recent tweeted at Mon Sep 10 01:06:35 +0000 2018
# 5178 tweets collected for hashtag libspill. Most recent tweeted at Mon Sep 10 00:25:21 +0000 2018
# 5278 tweets collected for hashtag libspill. Most recent tweeted at Sun Sep 09 23:40:11 +0000 2018
# 5378 tweets collected for hashtag libspill. Most recent tweeted at Sun Sep 09 22:29:16 +0000 2018
# 5478 tweets collected for hashtag libspill. Most recent tweeted at Sun Sep 09 21:23:56 +0000 2018
# 5578 tweets collected for hashtag libspill. Most recent tweeted at Sun Sep 09 15:04:34 +0000 2018
# 5678 tweets collected for hashtag libspill. Most recent tweeted at Sun Sep 09 11:15:00 +0000 2018
# 5778 tweets collected for hashtag libspill. Most recent tweeted at Sun Sep 09 05:44:40 +0000 2018
# 5878 tweets collected for hashtag libspill. Most recent tweeted at Sun Sep 09 01:11:26 +0000 2018
# 5978 tweets collected for hashtag libspill. Most recent tweeted at Sat Sep 08 23:37:27 +0000 2018
# 6078 tweets collected for hashtag libspill. Most recent tweeted at Sat Sep 08 22:27:04 +0000 2018

# %% [markdown]
# Write out the colleted tweets to a file, to save on future API calls:

# %%
# descriptive tweet details
print(tweet_collection[0]['created_at'])
print(tweet_collection[-1]['created_at'])
print(len(set([t['user']['id'] for t in tweet_collection])))
# Out:
# Mon Sep 17 13:03:45 +0000 2018
# Sat Sep 08 22:27:04 +0000 2018
# 6078
# 2534

# %%
tweets_filename = f"cached_tweets_{hashtag}.pkl"
with open(tweets_filename, 'wb') as f:
    pickle.dump(tweet_collection, f)

# %% [markdown]
# ## Part 2 - Document Cleaning

# %% [markdown]
# [Return to Contents](#Topic-1:-Text-Analysis)

# %% [markdown]
# Load tweets from the stored .pkl file:

# %%
tweets_filename = f"cached_tweets_{hashtag}.pkl"
tweet_collection = None
with open(tweets_filename, 'rb') as f:
    tweet_collection = pickle.load(f)

# %%
print("The number of raw uncleaned tweets is {}.".format(len(tweet_collection)))
# Out:
# The number of raw uncleaned tweets is 6078.

# %% [markdown]
# We perform a series of transformations in a pipeline to extract documents in the format and with the content we want, from the tweet collection:

# %%
def extract_documents(tweets):
    extract_text = lambda tweets: [tweet['full_text'] for tweet in tweets]
    convert_whitespace_chars = lambda tweets: [tweet.replace('\n', ' ').replace('\r', ' ').replace('\t', ' ') for tweet in tweets]
    squash_whitespace = lambda tweets: [tweet.replace('  ', ' ') for tweet in tweets]
    tokenize = lambda tweets: [tweet.strip().split() for tweet in tweets]
    strip_links = lambda tweets: [[token for token in tokens if "http" not in token] for tokens in tweets]
    strip_mentions = lambda tweets: [[token for token in tokens if token[0] is not '@'] for tokens in tweets]
    strip_hashtags = lambda tweets: [[token for token in tokens if token[0] is not '#'] for tokens in tweets]
    filter_empty = lambda tweets: [tweet for tweet in tweets if len(tweet) > 0]
    filter_retweets = lambda tweets: [tweet for tweet in tweets if tweet[0] != 'RT']
    rejoin = lambda tweets: [' '.join(tokens) for tokens in tweets]
    filter_short = lambda tweets: [tweet for tweet in tweets if len(tweet) > 40]
    
    documents = tweets
    
    for transformation in [
        extract_text,
        convert_whitespace_chars,
        squash_whitespace,
        tokenize,
        strip_links,
        strip_mentions,
        strip_hashtags,
        filter_empty,
        filter_retweets,
        rejoin,
        filter_short,
    ]:
        documents = transformation(documents)
    return documents

# %%
documents = extract_documents(tweet_collection)

# %% [markdown]
# We filter out a number of tweets (particularly retweets, since they're duplicate content), so let's see how many documents we have now:

# %%
print("The number of cleaned documents is {}.".format(len(documents)))
# Out:
# The number of cleaned documents is 941.

# %% [markdown]
# ## Part 3 - Watson NLU

# %% [markdown]
# [Return to Contents](#Topic-1:-Text-Analysis)

# %% [markdown]
# Create an NLU instance using IBM Watson SDK. Created using Sydney as the optional location selection:

# %%
url = "https://gateway-syd.watsonplatform.net/natural-language-understanding/api"
version = "2018-03-19"

natural_language_understanding = NaturalLanguageUnderstandingV1(
    version=version,
    iam_apikey=WATSON_NLU_API_KEY,
    url=url
)

# %% [markdown]
# Create a function which retrieves Watson NLU analyses for each of our documents using the NLU instance, and tracks progress:

# %%
def get_analyses(documents):
    entities = EntitiesOptions(sentiment=True, emotion=True, limit=5)
    sentiment = SentimentOptions()
    categories = CategoriesOptions()
    keywords = KeywordsOptions(sentiment=True, emotion=True, limit=5)
    emotion = EmotionOptions()
    document_count = 0
    
    def analyze(document):
        count = documents.index(document) + 1
        if count % 10 == 0 or count == len(documents):
            print("Analysing document #{} of {}...".format(count, len(documents)))
        return natural_language_understanding.analyze(
            text=document,
            features=Features(
                entities=entities,
                sentiment=sentiment,
                categories=categories,
                keywords=keywords,
                emotion=emotion,
            )
        )
    
    return [analyze(document) for document in documents]

# %%
watson_analyses = get_analyses(documents)
# Out:
# Analysing document #10 of 941...
# Analysing document #20 of 941...
# Analysing document #30 of 941...
# Analysing document #40 of 941...
# Analysing document #50 of 941...
# Analysing document #60 of 941...
# Analysing document #70 of 941...
# Analysing document #80 of 941...
# Analysing document #90 of 941...
# Analysing document #40 of 941...
# Analysing document #100 of 941...
# Analysing document #110 of 941...
# Analysing document #120 of 941...
# Analysing document #130 of 941...
# Analysing document #40 of 941...
# Analysing document #160 of 941...
# Analysing document #170 of 941...
# Analysing document #180 of 941...
# Analysing document #190 of 941...
# Analysing document #200 of 941...
# Analysing document #210 of 941...
# Analysing document #230 of 941...
# Analysing document #240 of 941...
# Analysing document #250 of 941...
# Analysing document #40 of 941...
# Analysing document #280 of 941...
# Analysing document #290 of 941...
# Analysing document #300 of 941...
# Analysing document #310 of 941...
# Analysing document #330 of 941...
# Analysing document #340 of 941...
# Analysing document #350 of 941...
# Analysing document #360 of 941...
# Analysing document #370 of 941...
# Analysing document #380 of 941...
# Analysing document #390 of 941...
# Analysing document #400 of 941...
# Analysing document #40 of 941...
# Analysing document #420 of 941...
# Analysing document #430 of 941...
# Analysing document #440 of 941...
# Analysing document #460 of 941...
# Analysing document #470 of 941...
# Analysing document #480 of 941...
# Analysing document #490 of 941...
# Analysing document #500 of 941...
# Analysing document #510 of 941...
# Analysing document #40 of 941...
# Analysing document #520 of 941...
# Analysing document #530 of 941...
# Analysing document #540 of 941...
# Analysing document #550 of 941...
# Analysing document #560 of 941...
# Analysing document #570 of 941...
# Analysing document #580 of 941...
# Analysing document #590 of 941...
# Analysing document #570 of 941...
# Analysing document #610 of 941...
# Analysing document #40 of 941...
# Analysing document #570 of 941...
# Analysing document #570 of 941...
# Analysing document #640 of 941...
# Analysing document #650 of 941...
# Analysing document #660 of 941...
# Analysing document #670 of 941...
# Analysing document #680 of 941...
# Analysing document #690 of 941...
# Analysing document #700 of 941...
# Analysing document #710 of 941...
# Analysing document #720 of 941...
# Analysing document #750 of 941...
# Analysing document #790 of 941...
# Analysing document #800 of 941...
# Analysing document #820 of 941...
# Analysing document #830 of 941...
# Analysing document #840 of 941...
# Analysing document #850 of 941...
# Analysing document #860 of 941...
# Analysing document #870 of 941...
# Analysing document #880 of 941...
# Analysing document #890 of 941...
# Analysing document #900 of 941...
# Analysing document #910 of 941...
# Analysing document #920 of 941...
# Analysing document #930 of 941...
# Analysing document #940 of 941...
# Analysing document #941 of 941...

# %% [markdown]
# Write out analyses to local disk, so we can perform analysis without refetching each time:

# %%
watson_analysis_filename = f"cached_watson_analysis_{hashtag}.pkl"

# %%
with open(watson_analysis_filename, 'wb') as f:
    pickle.dump(watson_analyses, f)

# %% [markdown]
# ## Part 4 - Analysis of Watson Output

# %% [markdown]
# [Return to Contents](#Topic-1:-Text-Analysis)

# %% [markdown]
# Load in our Watson analyses from disk, build five analysis objects with the information we need for our report, and write those objects out to disk.

# %%
watson_analyses = None
with open(watson_analysis_filename, 'rb') as f:
    watson_analyses = pickle.load(f)

# %% [markdown]
# ### Sentiment Analysis

# %%
sentiment_anaylsis = {}

# %%
sentiment_labels = [analysis.result['sentiment']['document']['label'] for analysis in watson_analyses]
sentiment_counter = Counter(sentiment_labels)
print(sentiment_counter)
# Out:
# Counter({'negative': 560, 'neutral': 216, 'positive': 165})

# %%
sentiment_anaylsis['positive_percentage'] = 100 * sentiment_counter['positive'] / sum(sentiment_counter.values())
sentiment_anaylsis['neutral_percentage'] = 100 * sentiment_counter['neutral'] / sum(sentiment_counter.values())
sentiment_anaylsis['negative_percentage'] = 100 * sentiment_counter['negative'] / sum(sentiment_counter.values())

# %%
print("The percentage of positive documents is: \t{:.2f}%".format(sentiment_anaylsis['positive_percentage']))
print("The percentage of negative documents is: \t{:.2f}%".format(sentiment_anaylsis['negative_percentage']))
print("The percentage of neutral documents is: \t{:.2f}%".format(sentiment_anaylsis['neutral_percentage']))
# Out:
# The percentage of positive documents is: 	17.53%
# The percentage of negative documents is: 	59.51%
# The percentage of neutral documents is: 	22.95%

# %%
pos_sentiment_scores = []
neg_sentiment_scores = []
neu_sentiment_scores = []
for analysis in watson_analyses:
    if analysis.result['sentiment']['document']['label'] == "positive":
        pos_sentiment_scores.append(analysis.result['sentiment']['document']['score'])
    elif analysis.result['sentiment']['document']['label'] == "negative":
        neg_sentiment_scores.append(analysis.result['sentiment']['document']['score'])
    elif analysis.result['sentiment']['document']['label'] == "neutral":
        neu_sentiment_scores.append(analysis.result['sentiment']['document']['score'])

# %%
sentiment_anaylsis['average_pos_score'] = sum(pos_sentiment_scores) / len(pos_sentiment_scores)
sentiment_anaylsis['std_dev_pos_score'] = statistics.stdev(pos_sentiment_scores)
sentiment_anaylsis['average_neg_score'] = sum(neg_sentiment_scores) / len(neg_sentiment_scores)
sentiment_anaylsis['std_dev_neg_score'] = statistics.stdev(neg_sentiment_scores)
sentiment_anaylsis['average_neu_score'] = sum(neu_sentiment_scores) / len(neu_sentiment_scores)
sentiment_anaylsis['std_dev_neu_score'] = statistics.stdev(neu_sentiment_scores)

# %%
print("The average of the positive sentiment scores is: {:.3f}\t(Std. Dev. = {:.3f})".format(
    sentiment_anaylsis['average_pos_score'], sentiment_anaylsis['std_dev_pos_score']))
print("The average of the negative sentiment scores is: {:.3f}\t(Std. Dev. = {:.3f})".format(
    sentiment_anaylsis['average_neg_score'], sentiment_anaylsis['std_dev_neg_score']))
print("The average of the neutral sentiment scores is: {:.3f}\t(Std. Dev. = {:.3f})".format(
    sentiment_anaylsis['average_neu_score'], sentiment_anaylsis['std_dev_neu_score']))
# Out:
# The average of the positive sentiment scores is: 0.571	(Std. Dev. = 0.288)
# The average of the negative sentiment scores is: -0.618	(Std. Dev. = 0.204)
# The average of the neutral sentiment scores is: 0.000	(Std. Dev. = 0.000)

# %% [markdown]
# ### Emotion  Analysis

# %%
emotion_analysis = {}

# %%
# document level emotion scores
for emotion in ['sadness', 'joy', 'fear', 'disgust', 'anger']:
    emotion_scores = [analysis.result['emotion']['document']['emotion'][emotion] for analysis in watson_analyses]

    average_emotion_score = sum(emotion_scores) / len(emotion_scores)
    emotion_score_std_dev = statistics.stdev(emotion_scores)
    emotion_analysis[emotion] = {'average_score': average_emotion_score, 'score_std_dev': emotion_score_std_dev}

# %%
for emotion in emotion_analysis.keys():
    print("The average score for '{}' is: \t{:.3f}\t(Std. Dev. = {:.3f})".format(
        emotion, emotion_analysis[emotion]['average_score'], emotion_analysis[emotion]['score_std_dev']))
# Out:
# The average score for 'sadness' is: 	0.292	(Std. Dev. = 0.178)
# The average score for 'joy' is: 	0.194	(Std. Dev. = 0.205)
# The average score for 'fear' is: 	0.140	(Std. Dev. = 0.113)
# The average score for 'disgust' is: 	0.240	(Std. Dev. = 0.189)
# The average score for 'anger' is: 	0.225	(Std. Dev. = 0.159)

# %% [markdown]
# ### Category Analysis

# %%
category_analysis = {}

# %%
analyses_categories = [analysis.result['categories'] for analysis in watson_analyses]
labels = lambda categories: [category['label'] for category in categories]
category_labels = []
[category_labels.extend(labels(categories)) for categories in analyses_categories]
categories_counter = Counter(category_labels)
category_analysis['count'] = len(categories_counter.values())
category_analysis['categories'] = dict(categories_counter)
display = 50
category_analysis['categories_common'] = categories_counter.most_common(display)

# %%
print("The total number of categories in the corpus is: \t{}\n".format(category_analysis['count']))
print("The frequencies of the top {} most common categories as follows: \n".format(display))
for category, count in category_analysis['categories_common']:
    print("{}  {}".format(category.ljust(95), count))
# Out:
# The total number of categories in the corpus is: 	465
#
# The frequencies of the top 50 most common categories as follows:
#
# /law, govt and politics/government                                                               275
# /law, govt and politics/government/parliament                                                    218
# /travel/tourist destinations/australia and new zealand                                           91
# /law, govt and politics/immigration                                                              90
# /news                                                                                            86
# /law, govt and politics/politics/elections                                                       74
# /art and entertainment/humor                                                                     65
# /business and industrial                                                                         53
# /art and entertainment/movies and tv/movies                                                      50
# /society/unrest and war                                                                          49
# /style and fashion/clothing/shorts                                                               47
# /law, govt and politics/politics                                                                 46
# /law, govt and politics                                                                          45
# /family and parenting/children                                                                   43
# /society/work/unions                                                                             40
# /education/school                                                                                33
# /food and drink                                                                                  30
# /law, govt and politics/politics/elections/presidential elections                                28
# /society/sex                                                                                     27
# /law, govt and politics/legal issues/legislation                                                 24
# /law, govt and politics/politics/political parties                                               22
# /art and entertainment/music                                                                     21
# /law, govt and politics/law enforcement/police                                                   18
# /travel/tourist destinations/canada                                                              16
# /art and entertainment/books and literature                                                      16
# /shopping/toys/puppets                                                                           16
# /business and industrial/energy/oil                                                              15
# /sports/running and jogging                                                                      15
# /society/crime/personal offense/homicide                                                         15
# /hobbies and interests/guitar                                                                    15
# /society/social institution/marriage                                                             14
# /society/racism                                                                                  13
# /technology and computing/consumer electronics/audio equipment/speakers                          13
# /sports/hockey                                                                                   13
# /health and fitness                                                                              13
# /law, govt and politics/government/courts and judiciary                                          13
# /society                                                                                         12
# /art and entertainment/theatre                                                                   12
# /science/mathematics/statistics                                                                  11
# /art and entertainment/movies and tv/television                                                  11
# /business and industrial/energy/oil/oil and gas prices                                           11
# /religion and spirituality/christianity                                                          11
# /science/social science/history                                                                  10
# /art and entertainment/shows and events/sports event                                             10
# /society/crime                                                                                   10
# /society/dating                                                                                  10
# /art and entertainment/dance                                                                     9
# /food and drink/beverages/non alcoholic beverages/coffee and tea                                 9
# /shopping/gifts                                                                                  9
# /health and fitness/disease                                                                      9

# %% [markdown]
# ### Entity Analysis

# %%
entity_analysis = {}

# %%
analyses_entities = [analysis.result['entities'] for analysis in watson_analyses]
raw_entities = lambda entities: [entity for entity in entities]
entities = []
[entities.extend(raw_entities(analyses_entity)) for analyses_entity in analyses_entities]

unique_entity_names = set([entity['text'] for entity in entities])

entity_analysis['count'] = len(unique_entity_names)
entity_analysis['entities'] = {}

for entity_name in unique_entity_names:
    sentiments = []
    for entity in entities:
        if entity['text'] == entity_name:
            sentiments.append(entity['sentiment']['score'])
    entity_analysis['entities'][entity_name] = {}
    entity_analysis['entities'][entity_name]['frequency'] = len(sentiments)
    entity_analysis['entities'][entity_name]['average_sentiment'] = sum(sentiments) / len(sentiments)
    if (len(sentiments) > 1):
        entity_analysis['entities'][entity_name]['sentiment_std_dev'] = statistics.stdev(sentiments)
    else:
        entity_analysis['entities'][entity_name]['sentiment_std_dev'] = 0

# %%
print("The total number of unique entities in the corpus is: \t{}\n".format(entity_analysis['count']))

for entity_name, stats in entity_analysis['entities'].items():
    print("Entity: {}average sentiment: {:6.3f}   (Std. Dev. = {:.3f})".format(entity_name.ljust(30), stats['average_sentiment'], stats['sentiment_std_dev']))
# Out:
# The total number of unique entities in the corpus is: 	357
#
# Entity: APH                           average sentiment: -0.430   (Std. Dev. = 0.000)
# Entity: Julia Gillard                 average sentiment: -0.842   (Std. Dev. = 0.000)
# Entity: Nelson LibSpill               average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Alexander Downer              average sentiment: -0.904   (Std. Dev. = 0.000)
# Entity: Julia Banks                   average sentiment: -0.435   (Std. Dev. = 0.354)
# Entity: Chrissy Pyne                  average sentiment: -0.576   (Std. Dev. = 0.000)
# Entity: Dave Smith                    average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Duddon                        average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Footy                         average sentiment: -0.757   (Std. Dev. = 0.000)
# Entity: Melbourne                     average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Catherine King                average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Conservative Party            average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Government                    average sentiment: -0.376   (Std. Dev. = 0.531)
# Entity: Andrew Bragg                  average sentiment: -0.534   (Std. Dev. = 0.000)
# Entity: president                     average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: two weeks                     average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Gillard                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Facebook                      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Porleen                       average sentiment: -0.836   (Std. Dev. = 0.000)
# Entity: Paris                         average sentiment: -0.234   (Std. Dev. = 0.203)
# Entity: Father Morrison               average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: banner drop                   average sentiment:  0.933   (Std. Dev. = 0.000)
# Entity: Duttons                       average sentiment: -0.260   (Std. Dev. = 0.368)
# Entity: Tennant Creek                 average sentiment: -0.547   (Std. Dev. = 0.000)
# Entity: Dawe                          average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: New Zealand                   average sentiment:  0.284   (Std. Dev. = 0.000)
# Entity: Morrison                      average sentiment: -0.227   (Std. Dev. = 0.448)
# Entity: ScoMo                         average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Trevor Ruthenberg             average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 12 days                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: New York                      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 3 weeks                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Commissioner                  average sentiment: -0.742   (Std. Dev. = 0.090)
# Entity: Abbott                        average sentiment: -0.065   (Std. Dev. = 0.429)
# Entity: Caroline Overington           average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Pyne                          average sentiment:  0.096   (Std. Dev. = 0.778)
# Entity: Richard Dowdy                 average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Wagga Wagga byelection        average sentiment: -0.412   (Std. Dev. = 0.000)
# Entity: one day                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: parliment Morrison            average sentiment: -0.608   (Std. Dev. = 0.000)
# Entity: Zoe                           average sentiment:  0.620   (Std. Dev. = 0.428)
# Entity: Dutton Govt                   average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 12-year                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Gerard Henderson              average sentiment: -0.191   (Std. Dev. = 0.330)
# Entity: F5E3️                        average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Malcolm Turnbull              average sentiment:  0.063   (Std. Dev. = 0.283)
# Entity: KGB                           average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: three years                   average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: scomo                         average sentiment:  0.399   (Std. Dev. = 0.000)
# Entity: football                      average sentiment:  0.464   (Std. Dev. = 0.000)
# Entity: Rosie                         average sentiment:  0.390   (Std. Dev. = 0.000)
# Entity: Henson                        average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Caterpillar Australia         average sentiment:  0.762   (Std. Dev. = 0.000)
# Entity: senator Amanda Stoker         average sentiment: -0.144   (Std. Dev. = 0.000)
# Entity: Greg Hunt                     average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Boris                         average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Mr Potatohead                 average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Daniel                        average sentiment: -0.282   (Std. Dev. = 0.000)
# Entity: Julie Bishop                  average sentiment: -0.075   (Std. Dev. = 0.213)
# Entity: PYNE                          average sentiment:  0.618   (Std. Dev. = 0.000)
# Entity: Lib Party                     average sentiment:  0.448   (Std. Dev. = 0.000)
# Entity: Russell Keog                  average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Canberra press gallery        average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Berejiklian                   average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Aidan                         average sentiment:  0.831   (Std. Dev. = 0.000)
# Entity: Brisbane                      average sentiment: -0.786   (Std. Dev. = 0.000)
# Entity: Scomo                         average sentiment:  0.675   (Std. Dev. = 0.000)
# Entity: Gina                          average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Warren                        average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Everso                        average sentiment:  0.546   (Std. Dev. = 0.000)
# Entity: Madame Tussauds               average sentiment:  0.853   (Std. Dev. = 0.000)
# Entity: Dave Sharma                   average sentiment:  0.269   (Std. Dev. = 0.466)
# Entity: David Sharma                  average sentiment:  0.708   (Std. Dev. = 0.000)
# Entity: UK                            average sentiment: -0.836   (Std. Dev. = 0.000)
# Entity: Canberra                      average sentiment: -0.054   (Std. Dev. = 0.532)
# Entity: 2 weeks                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: you..The Why..we              average sentiment: -0.729   (Std. Dev. = 0.000)
# Entity: Knight                        average sentiment:  0.587   (Std. Dev. = 0.000)
# Entity: Katharine Murphy              average sentiment:  0.395   (Std. Dev. = 0.387)
# Entity: TPP                           average sentiment: -0.691   (Std. Dev. = 0.000)
# Entity: 6%                            average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 44 percent                    average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 60 years                      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Labor Party                   average sentiment: -0.413   (Std. Dev. = 0.000)
# Entity: Matthias corman               average sentiment: -0.493   (Std. Dev. = 0.000)
# Entity: three days                    average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Greenpeace                    average sentiment: -0.432   (Std. Dev. = 0.053)
# Entity: Rhys Muldoon                  average sentiment: -0.170   (Std. Dev. = 0.000)
# Entity: Border Force                  average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Twitter                       average sentiment: -0.443   (Std. Dev. = 0.627)
# Entity: Tony BURKE                    average sentiment:  0.720   (Std. Dev. = 0.000)
# Entity: Julie                         average sentiment:  0.230   (Std. Dev. = 0.000)
# Entity: Victoria                      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Josh Frydenberg               average sentiment: -0.381   (Std. Dev. = 0.347)
# Entity: 29%                           average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Treasurer                     average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: ten months                    average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Dan                           average sentiment:  0.535   (Std. Dev. = 0.481)
# Entity: Ann Sudmalis                  average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Party                         average sentiment: -0.423   (Std. Dev. = 0.000)
# Entity: David                         average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Warren Entsch                 average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Howard back Sharma            average sentiment:  0.453   (Std. Dev. = 0.000)
# Entity: Senator                       average sentiment:  0.417   (Std. Dev. = 0.000)
# Entity: Scottie                       average sentiment:  0.478   (Std. Dev. = 0.000)
# Entity: Mitcham                       average sentiment: -0.554   (Std. Dev. = 0.000)
# Entity: Farr                          average sentiment:  0.015   (Std. Dev. = 0.000)
# Entity: PM Turnbull                   average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Liberal Govt                  average sentiment: -0.329   (Std. Dev. = 0.000)
# Entity: High Court                    average sentiment: -0.013   (Std. Dev. = 0.393)
# Entity: Australia.                    average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: PETER DUTTON                  average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 200,000 dollars               average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Nats                          average sentiment: -0.123   (Std. Dev. = 0.174)
# Entity: Menzies                       average sentiment: -0.564   (Std. Dev. = 0.000)
# Entity: Senate                        average sentiment: -0.136   (Std. Dev. = 0.459)
# Entity: Priscilla Queen               average sentiment:  0.224   (Std. Dev. = 0.000)
# Entity: Barry..                       average sentiment:  0.362   (Std. Dev. = 0.000)
# Entity: Mathias Cormann               average sentiment:  0.232   (Std. Dev. = 0.296)
# Entity: Kevin Hogan                   average sentiment:  0.633   (Std. Dev. = 0.000)
# Entity: Kerryn Phelps                 average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: official                      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 45%                           average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: SkyNews                       average sentiment: -0.810   (Std. Dev. = 0.000)
# Entity: Morrison Government           average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: $3                            average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Chris Bowen                   average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Kevin Rudd                    average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Catherine O’Regan             average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: two years                     average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Frydenberg                    average sentiment: -0.254   (Std. Dev. = 0.000)
# Entity: ALP                           average sentiment: -0.288   (Std. Dev. = 0.499)
# Entity: four minutes                  average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Gees                          average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: David shearman                average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Craig Kelly                   average sentiment: -0.351   (Std. Dev. = 0.000)
# Entity: Mp                            average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Wentworth                     average sentiment:  0.214   (Std. Dev. = 0.318)
# Entity: liberals                      average sentiment: -0.374   (Std. Dev. = 0.000)
# Entity: 3 years                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Trumble                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Morris                        average sentiment:  0.653   (Std. Dev. = 0.000)
# Entity: 8%                            average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: twitter                       average sentiment:  0.321   (Std. Dev. = 0.454)
# Entity: Aus                           average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Canavan                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Tony Abbott                   average sentiment: -0.158   (Std. Dev. = 0.264)
# Entity: rape                          average sentiment: -0.471   (Std. Dev. = 0.000)
# Entity: Huw Parkinson                 average sentiment: -0.542   (Std. Dev. = 0.000)
# Entity: Nelson                        average sentiment: -0.555   (Std. Dev. = 0.000)
# Entity: Christopher Pyne              average sentiment: -0.659   (Std. Dev. = 0.112)
# Entity: 100%                          average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: LinkedIn                      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: $550                          average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Daryl Maguire                 average sentiment: -0.772   (Std. Dev. = 0.000)
# Entity: 30%                           average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 5 years                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Hawks                         average sentiment:  0.501   (Std. Dev. = 0.000)
# Entity: Lucy Gichuhi                  average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Phelps                        average sentiment: -0.318   (Std. Dev. = 0.000)
# Entity: Nero Wolfe                    average sentiment: -0.288   (Std. Dev. = 0.000)
# Entity: twenty years                  average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Simon                         average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Flummery                      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Pamela Williams               average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Craig Laundy.                 average sentiment: -0.476   (Std. Dev. = 0.000)
# Entity: muppets                       average sentiment:  0.439   (Std. Dev. = 0.000)
# Entity: Christopher Pine              average sentiment: -0.717   (Std. Dev. = 0.000)
# Entity: W. Peters                     average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: parliament                    average sentiment: -0.124   (Std. Dev. = 0.176)
# Entity: 6 weeks                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Matthias                      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Malcolm Who                   average sentiment:  0.499   (Std. Dev. = 0.000)
# Entity: Qld                           average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Bill                          average sentiment: -0.491   (Std. Dev. = 0.000)
# Entity: Waggapocalypse                average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Liberal party                 average sentiment: -0.486   (Std. Dev. = 0.280)
# Entity: JBish                         average sentiment: -0.674   (Std. Dev. = 0.000)
# Entity: $200,000                      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Tony Wrecker                  average sentiment: -0.459   (Std. Dev. = 0.000)
# Entity: Tony                          average sentiment:  0.053   (Std. Dev. = 0.465)
# Entity: Gary Spence                   average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Roman Quaedvlieg              average sentiment: -0.359   (Std. Dev. = 0.000)
# Entity: Japan                         average sentiment: -0.813   (Std. Dev. = 0.000)
# Entity: treasurer                     average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Maury Chaykin                 average sentiment: -0.549   (Std. Dev. = 0.000)
# Entity: Bragg                         average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 3 Years                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Turnbull                      average sentiment: -0.196   (Std. Dev. = 0.480)
# Entity: Michael Linn                  average sentiment: -0.408   (Std. Dev. = 0.000)
# Entity: China                         average sentiment:  0.433   (Std. Dev. = 0.000)
# Entity: LNP                           average sentiment: -0.312   (Std. Dev. = 0.385)
# Entity: Dtton                         average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: pwer                          average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Senator Gichuhi               average sentiment: -0.329   (Std. Dev. = 0.000)
# Entity: Clarke                        average sentiment: -0.630   (Std. Dev. = 0.000)
# Entity: Wagga Corman                  average sentiment: -0.347   (Std. Dev. = 0.000)
# Entity: murder                        average sentiment: -0.648   (Std. Dev. = 0.172)
# Entity: LNP.                          average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Ley                           average sentiment: -0.344   (Std. Dev. = 0.000)
# Entity: Canada                        average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Kelly O'Dwyer                 average sentiment:  0.448   (Std. Dev. = 0.000)
# Entity: Ross Vasta                    average sentiment:  0.587   (Std. Dev. = 0.000)
# Entity: C. Heston                     average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Fed                           average sentiment: -0.348   (Std. Dev. = 0.000)
# Entity: Sharma                        average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: three weeks                   average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Rudd                          average sentiment: -0.213   (Std. Dev. = 0.368)
# Entity: Sukkar                        average sentiment: -0.743   (Std. Dev. = 0.000)
# Entity: Two weeks                     average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: senator Lucy Senator Gichuhi  average sentiment: -0.505   (Std. Dev. = 0.000)
# Entity: Quantum Mechanics Bastion Caucusaverage sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Antony Green                  average sentiment: -0.387   (Std. Dev. = 0.000)
# Entity: 30 years                      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Liberal Party                 average sentiment: -0.209   (Std. Dev. = 0.443)
# Entity: lnp                           average sentiment: -0.526   (Std. Dev. = 0.005)
# Entity: Icefight Australia            average sentiment:  0.284   (Std. Dev. = 0.000)
# Entity: Rupert Murdoch                average sentiment: -0.474   (Std. Dev. = 0.000)
# Entity: WW2                           average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Joshie                        average sentiment: -0.251   (Std. Dev. = 0.000)
# Entity: Govt                          average sentiment: -0.079   (Std. Dev. = 0.541)
# Entity: WA                            average sentiment: -0.368   (Std. Dev. = 0.000)
# Entity: 3 days                        average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: ICAC                          average sentiment: -0.235   (Std. Dev. = 0.000)
# Entity: Peter Peter Who               average sentiment:  0.622   (Std. Dev. = 0.000)
# Entity: Simon Birmingham              average sentiment: -0.848   (Std. Dev. = 0.000)
# Entity: Tanya                         average sentiment: -0.375   (Std. Dev. = 0.000)
# Entity: libspill                      average sentiment: -0.199   (Std. Dev. = 0.281)
# Entity: Wagga Wagga                   average sentiment: -0.306   (Std. Dev. = 0.307)
# Entity: Julia                         average sentiment: -0.524   (Std. Dev. = 0.000)
# Entity: Angus Taylor                  average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 10 years                      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Leigh Sales                   average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: five years                    average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: senate                        average sentiment: -0.493   (Std. Dev. = 0.000)
# Entity: Coalition                     average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Mr Turnbull                   average sentiment: -0.427   (Std. Dev. = 0.000)
# Entity: Warringah                     average sentiment: -0.317   (Std. Dev. = 0.000)
# Entity: Rupert                        average sentiment: -0.028   (Std. Dev. = 0.584)
# Entity: Parliament House              average sentiment: -0.012   (Std. Dev. = 0.153)
# Entity: Shouty Mcshoutface            average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: New York.                     average sentiment:  0.959   (Std. Dev. = 0.000)
# Entity: Canberra Times                average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: assault                       average sentiment: -0.474   (Std. Dev. = 0.000)
# Entity: hundred dollar                average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Old MacDonald                 average sentiment: -0.514   (Std. Dev. = 0.000)
# Entity: verballed                     average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Lib                           average sentiment: -0.553   (Std. Dev. = 0.000)
# Entity: Beazley                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: tony abbott                   average sentiment: -0.714   (Std. Dev. = 0.000)
# Entity: Jimmy                         average sentiment: -0.364   (Std. Dev. = 0.000)
# Entity: Pastor Morrison               average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: prime minister                average sentiment:  0.479   (Std. Dev. = 0.047)
# Entity: Pete                          average sentiment: -0.913   (Std. Dev. = 0.000)
# Entity: Alan Jones                    average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: crossbench                    average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Muppet Morrison               average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Australia                     average sentiment:  0.089   (Std. Dev. = 0.410)
# Entity: Turdbull                      average sentiment:  0.642   (Std. Dev. = 0.000)
# Entity: GladysBerejiklian             average sentiment: -0.780   (Std. Dev. = 0.000)
# Entity: Kevin                         average sentiment: -0.665   (Std. Dev. = 0.000)
# Entity: Turnbull Govt                 average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: MP                            average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Leigh                         average sentiment:  0.783   (Std. Dev. = 0.000)
# Entity: Bill Shorten                  average sentiment: -0.486   (Std. Dev. = 0.000)
# Entity: Ms Banks                      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: J. Edgar Tuber                average sentiment: -0.547   (Std. Dev. = 0.000)
# Entity: Dutton                        average sentiment: -0.104   (Std. Dev. = 0.493)
# Entity: Scumo                         average sentiment: -0.827   (Std. Dev. = 0.000)
# Entity: AUSTRALIA                     average sentiment: -0.752   (Std. Dev. = 0.000)
# Entity: political Party               average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Morrison Govt                 average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Hastie                        average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Parliament                    average sentiment: -0.341   (Std. Dev. = 0.355)
# Entity: Trumbull                      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 10 seconds                    average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Gilmore                       average sentiment: -0.693   (Std. Dev. = 0.000)
# Entity: Scott                         average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Tony Wright                   average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 30 mins                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Henderson                     average sentiment: -0.373   (Std. Dev. = 0.040)
# Entity: Mathias                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Hong Kong                     average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Senator Lucy Gichuhi          average sentiment: -0.594   (Std. Dev. = 0.000)
# Entity: Jim Henson                    average sentiment: -0.738   (Std. Dev. = 0.000)
# Entity: Scotty                        average sentiment: -0.777   (Std. Dev. = 0.000)
# Entity: Albury                        average sentiment: -0.564   (Std. Dev. = 0.000)
# Entity: Scott Morrison                average sentiment: -0.362   (Std. Dev. = 0.237)
# Entity: Murdoch                       average sentiment: -0.676   (Std. Dev. = 0.089)
# Entity: Robert Menzies                average sentiment: -0.758   (Std. Dev. = 0.000)
# Entity: 27426 Links                   average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Four minutes                  average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: The Sydney Morning Herald     average sentiment:  0.435   (Std. Dev. = 0.000)
# Entity: da house                      average sentiment:  0.871   (Std. Dev. = 0.000)
# Entity: SloMo Morrison                average sentiment: -0.637   (Std. Dev. = 0.000)
# Entity: PM                            average sentiment: -0.810   (Std. Dev. = 0.000)
# Entity: FRFWs                         average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Peter Dutton                  average sentiment: -0.140   (Std. Dev. = 0.356)
# Entity: Cathy                         average sentiment:  0.546   (Std. Dev. = 0.000)
# Entity: Devanand                      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Dutton AG Porter              average sentiment:  0.460   (Std. Dev. = 0.000)
# Entity: Libspill                      average sentiment: -0.183   (Std. Dev. = 0.317)
# Entity: 95%                           average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: NSW                           average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Finance Minister              average sentiment:  0.156   (Std. Dev. = 0.220)
# Entity: Devanand Sharma               average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: libspill Labor                average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Devanand David                average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Terry                         average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: House of Representatives      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: George                        average sentiment: -0.374   (Std. Dev. = 0.000)
# Entity: peter dutton                  average sentiment: -0.714   (Std. Dev. = 0.000)
# Entity: LNP Cabinet                   average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Deb Frecklington              average sentiment: -0.692   (Std. Dev. = 0.000)
# Entity: 44%                           average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 3 year                        average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Cronulla Sharks               average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Barnaby Joyce                 average sentiment:  0.157   (Std. Dev. = 0.782)
# Entity: Natasha                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 56%                           average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Hosea                         average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Peter                         average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: John Hewson                   average sentiment:  0.143   (Std. Dev. = 0.202)
# Entity: 5%                            average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 5 year                        average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Lucy G                        average sentiment: -0.854   (Std. Dev. = 0.000)
# Entity: PVO                           average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Hawthorn                      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Tony ABBOTT                   average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 41%                           average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Littleproud                   average sentiment: -0.864   (Std. Dev. = 0.000)
# Entity: $800                          average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Nationals                     average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: paliament                     average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: ABC                           average sentiment:  0.153   (Std. Dev. = 0.265)
# Entity: Josh                          average sentiment: -0.427   (Std. Dev. = 0.558)
# Entity: Dutch Reagan                  average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Libs                          average sentiment: -0.345   (Std. Dev. = 0.454)
# Entity: South Australia               average sentiment: -0.319   (Std. Dev. = 0.000)
# Entity: Malcom Turnbull               average sentiment: -0.681   (Std. Dev. = 0.000)
# Entity: Kate Jenkins                  average sentiment: -0.757   (Std. Dev. = 0.112)
# Entity: Malcolm                       average sentiment: -0.161   (Std. Dev. = 0.574)
# Entity: 3 months                      average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: F3A9                         average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Josh Frydenburg               average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Kathryn                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Malcolm Turnball              average sentiment:  0.799   (Std. Dev. = 0.000)
# Entity: The New Daily                 average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: four minute                   average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Bridget McKenzie              average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Dutti                         average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Bishop                        average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Quaedvlieg                    average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: 11%                           average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: McMahon                       average sentiment:  0.000   (Std. Dev. = 0.000)
# Entity: Prime Minister                average sentiment:  0.341   (Std. Dev. = 0.332)
# Entity: Labor                         average sentiment: -0.565   (Std. Dev. = 0.243)

# %% [markdown]
# ### Keyword Analysis

# %%
keyword_analysis = {}

# %%
analyses_keywords = [analysis.result['keywords'] for analysis in watson_analyses]
raw_keywords = lambda keywords: [keyword for keyword in keywords]
keywords = []
[keywords.extend(raw_keywords(analyses_keyword)) for analyses_keyword in analyses_keywords]

unique_keyword_names = set([keyword['text'] for keyword in keywords])

keyword_analysis['count'] = len(unique_keyword_names)
keyword_analysis['keywords'] = {}

for keyword_name in unique_keyword_names:
    sentiments = []
    for keyword in keywords:
        if keyword['text'] == keyword_name:
            sentiments.append(keyword['sentiment']['score'])
    keyword_analysis['keywords'][keyword_name] = {}
    keyword_analysis['keywords'][keyword_name]['frequency'] = len(sentiments)
    keyword_analysis['keywords'][keyword_name]['average_sentiment'] = sum(sentiments) / len(sentiments)
    if (len(sentiments) > 1):
        keyword_analysis['keywords'][keyword_name]['sentiment_std_dev'] = statistics.stdev(sentiments)
    else:
        keyword_analysis['keywords'][keyword_name]['sentiment_std_dev'] = 0

# %%
print("The total number of keywords in the corpus is: \t{}\n".format(keyword_analysis['count']))

for keyword_name, stats in keyword_analysis['keywords'].items():
    print("Keyword: {}Average sentiment: {:6.3f}   (Std. Dev. = {:.3f})".format(keyword_name.ljust(30), stats['average_sentiment'], stats['sentiment_std_dev']))
# Out:
# The total number of keywords in the corpus is: 	2048
#
# Keyword: best credentialed leader      Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Tick                          Average sentiment:  0.205   (Std. Dev. = 0.000)
# Keyword: Idiotic Littleproud           Average sentiment: -0.864   (Std. Dev. = 0.000)
# Keyword: Nelson LibSpill               Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: ante                          Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: senator Lucy Senator          Average sentiment: -0.505   (Std. Dev. = 0.000)
# Keyword: recent According              Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: visit                         Average sentiment: -0.502   (Std. Dev. = 0.000)
# Keyword: Aussie                        Average sentiment:  0.336   (Std. Dev. = 0.475)
# Keyword: Duddon                        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: confected poll Barry..        Average sentiment:  0.362   (Std. Dev. = 0.000)
# Keyword: transcript                    Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Hi                            Average sentiment: -0.441   (Std. Dev. = 0.080)
# Keyword: brain cell government         Average sentiment: -0.572   (Std. Dev. = 0.000)
# Keyword: ministers                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: line                          Average sentiment: -0.211   (Std. Dev. = 0.000)
# Keyword: chairs                        Average sentiment: -0.387   (Std. Dev. = 0.000)
# Keyword: government cars               Average sentiment:  0.305   (Std. Dev. = 0.000)
# Keyword: leadership                    Average sentiment: -0.280   (Std. Dev. = 0.507)
# Keyword: leadership spills             Average sentiment: -0.749   (Std. Dev. = 0.000)
# Keyword: Muppet Show Theme             Average sentiment:  0.896   (Std. Dev. = 0.000)
# Keyword: Poor                          Average sentiment: -0.791   (Std. Dev. = 0.000)
# Keyword: secret agreement              Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Poor Pete                     Average sentiment: -0.913   (Std. Dev. = 0.000)
# Keyword: cards                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: sort                          Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: constituents                  Average sentiment: -0.590   (Std. Dev. = 0.114)
# Keyword: Aussie dollars                Average sentiment: -0.271   (Std. Dev. = 0.000)
# Keyword: RESIDENTS                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Gillard                       Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: answer                        Average sentiment:  0.139   (Std. Dev. = 0.310)
# Keyword: Fucking Problem               Average sentiment: -0.692   (Std. Dev. = 0.000)
# Keyword: new generation                Average sentiment: -0.552   (Std. Dev. = 0.000)
# Keyword: shit job                      Average sentiment: -0.901   (Std. Dev. = 0.000)
# Keyword: SANFL                         Average sentiment: -0.319   (Std. Dev. = 0.000)
# Keyword: libspill petition             Average sentiment: -0.409   (Std. Dev. = 0.000)
# Keyword: headline release              Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: morning                       Average sentiment: -0.620   (Std. Dev. = 0.000)
# Keyword: Power prices                  Average sentiment: -0.439   (Std. Dev. = 0.000)
# Keyword: edge. h/t                     Average sentiment:  0.658   (Std. Dev. = 0.000)
# Keyword: questions                     Average sentiment: -0.158   (Std. Dev. = 0.246)
# Keyword: Verbal diarrhoea              Average sentiment: -0.498   (Std. Dev. = 0.000)
# Keyword: potato                        Average sentiment:  0.601   (Std. Dev. = 0.000)
# Keyword: sword                         Average sentiment: -0.671   (Std. Dev. = 0.329)
# Keyword: bad thing                     Average sentiment: -0.836   (Std. Dev. = 0.000)
# Keyword: straight                      Average sentiment: -0.151   (Std. Dev. = 0.213)
# Keyword: authoritarianism              Average sentiment: -0.235   (Std. Dev. = 0.000)
# Keyword: obvious corrupt practices     Average sentiment: -0.862   (Std. Dev. = 0.000)
# Keyword: CI                            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: parliment Morrison            Average sentiment: -0.608   (Std. Dev. = 0.000)
# Keyword: Node                          Average sentiment:  0.779   (Std. Dev. = 0.000)
# Keyword: following beats               Average sentiment:  0.476   (Std. Dev. = 0.000)
# Keyword: Dutton Govt                   Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: precisely fuck                Average sentiment: -0.693   (Std. Dev. = 0.000)
# Keyword: unelected PM                  Average sentiment: -0.599   (Std. Dev. = 0.000)
# Keyword: financial record              Average sentiment: -0.522   (Std. Dev. = 0.000)
# Keyword: plate                         Average sentiment:  0.760   (Std. Dev. = 0.000)
# Keyword: Uh                            Average sentiment: -0.766   (Std. Dev. = 0.000)
# Keyword: Malcolm Turnbull              Average sentiment:  0.092   (Std. Dev. = 0.260)
# Keyword: base                          Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: belief                        Average sentiment:  0.320   (Std. Dev. = 0.000)
# Keyword: mob                           Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Recent events                 Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: blame                         Average sentiment: -0.517   (Std. Dev. = 0.000)
# Keyword: -Abbott/Turnbull/Morrison     Average sentiment:  0.395   (Std. Dev. = 0.000)
# Keyword: yesterdays shambles           Average sentiment: -0.608   (Std. Dev. = 0.000)
# Keyword: indi_is                       Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Rudd spill                    Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Soooo.. first rave            Average sentiment:  0.871   (Std. Dev. = 0.000)
# Keyword: world.                        Average sentiment:  0.681   (Std. Dev. = 0.000)
# Keyword: PM.                           Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: penalty rate                  Average sentiment: -0.352   (Std. Dev. = 0.000)
# Keyword: Folks                         Average sentiment: -0.818   (Std. Dev. = 0.000)
# Keyword: Mr Potatohead                 Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: toons                         Average sentiment: -0.511   (Std. Dev. = 0.058)
# Keyword: Julie Bishop                  Average sentiment: -0.086   (Std. Dev. = 0.228)
# Keyword: younger voters                Average sentiment:  0.377   (Std. Dev. = 0.000)
# Keyword: Everybody                     Average sentiment:  0.181   (Std. Dev. = 0.256)
# Keyword: revenge mission               Average sentiment: -0.532   (Std. Dev. = 0.000)
# Keyword: til                           Average sentiment: -0.631   (Std. Dev. = 0.025)
# Keyword: elections                     Average sentiment: -0.206   (Std. Dev. = 0.449)
# Keyword: crime                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: phones                        Average sentiment: -0.632   (Std. Dev. = 0.000)
# Keyword: 🤓😝                            Average sentiment: -0.495   (Std. Dev. = 0.000)
# Keyword: reference                     Average sentiment: -0.479   (Std. Dev. = 0.000)
# Keyword: roof                          Average sentiment: -0.863   (Std. Dev. = 0.000)
# Keyword: Billboard trucks              Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: majority                      Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Katharine Murphy              Average sentiment:  0.387   (Std. Dev. = 0.547)
# Keyword: fatally flawed captain        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Matthias corman               Average sentiment: -0.493   (Std. Dev. = 0.000)
# Keyword: regulation                    Average sentiment: -0.626   (Std. Dev. = 0.000)
# Keyword: schemozzle                    Average sentiment: -0.397   (Std. Dev. = 0.000)
# Keyword: evasive statements            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Interesting Morrison          Average sentiment: -0.862   (Std. Dev. = 0.000)
# Keyword: campaign team                 Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: new PM                        Average sentiment: -0.229   (Std. Dev. = 0.341)
# Keyword: Twitter                       Average sentiment: -0.886   (Std. Dev. = 0.000)
# Keyword: Opposition Leader             Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Julie                         Average sentiment:  0.230   (Std. Dev. = 0.000)
# Keyword: Hypocrites                    Average sentiment: -0.584   (Std. Dev. = 0.000)
# Keyword: Tudge                         Average sentiment:  0.445   (Std. Dev. = 0.000)
# Keyword: prime meat Water              Average sentiment: -0.598   (Std. Dev. = 0.058)
# Keyword: ‘Labor                        Average sentiment: -0.369   (Std. Dev. = 0.000)
# Keyword: publicity                     Average sentiment: -0.573   (Std. Dev. = 0.000)
# Keyword: votes                         Average sentiment: -0.281   (Std. Dev. = 0.397)
# Keyword: happy clappy muppet           Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: response                      Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: margin                        Average sentiment: -0.693   (Std. Dev. = 0.000)
# Keyword: kettle                        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Look away ye                  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: David                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: sure means                    Average sentiment:  0.456   (Std. Dev. = 0.000)
# Keyword: eye                           Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: yet.                          Average sentiment: -0.531   (Std. Dev. = 0.000)
# Keyword: masteR.mind                   Average sentiment: -0.417   (Std. Dev. = 0.000)
# Keyword: PM Turnbull                   Average sentiment: -0.444   (Std. Dev. = 0.385)
# Keyword: Australia.                    Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Morrison folder               Average sentiment: -0.466   (Std. Dev. = 0.000)
# Keyword: surprising new discovery      Average sentiment:  0.781   (Std. Dev. = 0.000)
# Keyword: Irony                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: war room                      Average sentiment: -0.501   (Std. Dev. = 0.000)
# Keyword: voodoo doll                   Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: gee                           Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: ... ...                       Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Mathias Cormann               Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: protection racket             Average sentiment:  0.326   (Std. Dev. = 0.461)
# Keyword: policy not personality        Average sentiment: -0.467   (Std. Dev. = 0.000)
# Keyword: refusal                       Average sentiment: -0.723   (Std. Dev. = 0.000)
# Keyword: lib                           Average sentiment: -0.619   (Std. Dev. = 0.000)
# Keyword: amounts                       Average sentiment: -0.723   (Std. Dev. = 0.000)
# Keyword: issue                         Average sentiment: -0.430   (Std. Dev. = 0.307)
# Keyword: re-election                   Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: unsafe workplace              Average sentiment: -0.585   (Std. Dev. = 0.000)
# Keyword: New generation leadership     Average sentiment: -0.643   (Std. Dev. = 0.000)
# Keyword: Kerryn Phelps                 Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: backwash                      Average sentiment: -0.785   (Std. Dev. = 0.000)
# Keyword: Dear Scott                    Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: PMO                           Average sentiment: -0.167   (Std. Dev. = 0.982)
# Keyword: echo chamber                  Average sentiment:  0.695   (Std. Dev. = 0.000)
# Keyword: perfect advertisement         Average sentiment:  0.522   (Std. Dev. = 0.000)
# Keyword: preferred PM poll             Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: interpretive display          Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: candidates                    Average sentiment: -0.578   (Std. Dev. = 0.000)
# Keyword: election victory              Average sentiment: -0.340   (Std. Dev. = 0.481)
# Keyword: Arse Prime Minister           Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: players                       Average sentiment: -0.664   (Std. Dev. = 0.000)
# Keyword: story                         Average sentiment: -0.058   (Std. Dev. = 0.596)
# Keyword: Anybody                       Average sentiment:  0.611   (Std. Dev. = 0.000)
# Keyword: school alumni Facebook        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: MoFo                          Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: ALP                           Average sentiment: -0.185   (Std. Dev. = 0.468)
# Keyword: LinkedIn profile              Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Gees                          Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: pump                          Average sentiment: -0.295   (Std. Dev. = 0.000)
# Keyword: reactions                     Average sentiment:  0.828   (Std. Dev. = 0.000)
# Keyword: discipline                    Average sentiment:  0.522   (Std. Dev. = 0.000)
# Keyword: bullying verdict              Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: HC                            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: mini series                   Average sentiment: -0.899   (Std. Dev. = 0.000)
# Keyword: TPP newspolls                 Average sentiment: -0.691   (Std. Dev. = 0.000)
# Keyword: real Mathias Cormann          Average sentiment:  0.617   (Std. Dev. = 0.000)
# Keyword: bullshit                      Average sentiment: -0.787   (Std. Dev. = 0.032)
# Keyword: executioner¡s eligibility FFS Average sentiment: -0.537   (Std. Dev. = 0.000)
# Keyword: Wentworth                     Average sentiment: -0.187   (Std. Dev. = 0.530)
# Keyword: shambles                      Average sentiment: -0.383   (Std. Dev. = 0.000)
# Keyword: emissions                     Average sentiment: -0.234   (Std. Dev. = 0.000)
# Keyword: news                          Average sentiment:  0.099   (Std. Dev. = 0.606)
# Keyword: ain’t it?                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: pundits                       Average sentiment: -0.894   (Std. Dev. = 0.000)
# Keyword: farmers                       Average sentiment: -0.360   (Std. Dev. = 0.000)
# Keyword: Lem                           Average sentiment:  0.302   (Std. Dev. = 0.000)
# Keyword: Aus                           Average sentiment: -0.291   (Std. Dev. = 0.412)
# Keyword: threat                        Average sentiment: -0.709   (Std. Dev. = 0.262)
# Keyword: partisan campaign             Average sentiment: -0.413   (Std. Dev. = 0.000)
# Keyword: Huw Parkinson                 Average sentiment: -0.542   (Std. Dev. = 0.000)
# Keyword: decade                        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: cold war w/                   Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: hands                         Average sentiment:  0.031   (Std. Dev. = 0.626)
# Keyword: Bullying WTF                  Average sentiment: -0.846   (Std. Dev. = 0.000)
# Keyword: meddling                      Average sentiment: -0.889   (Std. Dev. = 0.000)
# Keyword: liars Stakes                  Average sentiment:  0.401   (Std. Dev. = 0.000)
# Keyword: slogans                       Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Aus media                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: backbenchers                  Average sentiment: -0.757   (Std. Dev. = 0.000)
# Keyword: Credibility                   Average sentiment: -0.711   (Std. Dev. = 0.000)
# Keyword: easy protest vote             Average sentiment: -0.580   (Std. Dev. = 0.000)
# Keyword: vile anti-Quadvlieg pics      Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: confidence                    Average sentiment:  0.464   (Std. Dev. = 0.656)
# Keyword: term                          Average sentiment: -0.591   (Std. Dev. = 0.000)
# Keyword: LNP gang members              Average sentiment: -0.651   (Std. Dev. = 0.000)
# Keyword: debut comedy routine          Average sentiment: -0.711   (Std. Dev. = 0.000)
# Keyword: gt                            Average sentiment: -0.401   (Std. Dev. = 0.119)
# Keyword: table                         Average sentiment: -0.618   (Std. Dev. = 0.000)
# Keyword: govt                          Average sentiment: -0.374   (Std. Dev. = 0.297)
# Keyword: vulnerability                 Average sentiment:  0.236   (Std. Dev. = 0.000)
# Keyword: navel-gazing-ego-bashing continuesAverage sentiment: -0.564   (Std. Dev. = 0.000)
# Keyword: Retweet                       Average sentiment: -0.300   (Std. Dev. = 0.000)
# Keyword: mouth                         Average sentiment:  0.687   (Std. Dev. = 0.000)
# Keyword: dirt cheap                    Average sentiment: -0.579   (Std. Dev. = 0.000)
# Keyword: perfect team.                 Average sentiment:  0.818   (Std. Dev. = 0.000)
# Keyword: W. Peters                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: TP                            Average sentiment: -0.224   (Std. Dev. = 0.000)
# Keyword: recent ahem                   Average sentiment: -0.623   (Std. Dev. = 0.000)
# Keyword: deficit                       Average sentiment: -0.684   (Std. Dev. = 0.000)
# Keyword: conservatives                 Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: bullying                      Average sentiment: -0.500   (Std. Dev. = 0.206)
# Keyword: spectacular leadership coup   Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: machinations                  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: drive-by                      Average sentiment: -0.917   (Std. Dev. = 0.000)
# Keyword: Fozzy Bear                    Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: grand gesture                 Average sentiment:  0.363   (Std. Dev. = 0.000)
# Keyword: Matthias                      Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: leadership knife-fight        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: head.                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: circus Scott Morrison         Average sentiment: -0.366   (Std. Dev. = 0.000)
# Keyword: holes                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Internal rumblings            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: preselection opponent         Average sentiment: -0.528   (Std. Dev. = 0.000)
# Keyword: state MPs                     Average sentiment: -0.753   (Std. Dev. = 0.000)
# Keyword: Democracy                     Average sentiment:  0.534   (Std. Dev. = 0.000)
# Keyword: media commentators            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: defence                       Average sentiment:  0.524   (Std. Dev. = 0.000)
# Keyword: treasurer                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: denial                        Average sentiment: -0.785   (Std. Dev. = 0.000)
# Keyword: intelligent design            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Turnbull                      Average sentiment: -0.237   (Std. Dev. = 0.446)
# Keyword: icebergs                      Average sentiment: -0.348   (Std. Dev. = 0.000)
# Keyword: chocolate bar                 Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Sulfurous Hate                Average sentiment: -0.731   (Std. Dev. = 0.000)
# Keyword: Gays Are Revolting            Average sentiment: -0.561   (Std. Dev. = 0.000)
# Keyword: invitation                    Average sentiment:  0.252   (Std. Dev. = 0.000)
# Keyword: copy                          Average sentiment:  0.288   (Std. Dev. = 0.000)
# Keyword: Mechanics Bastion Caucus      Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Senator Gichuhi               Average sentiment: -0.329   (Std. Dev. = 0.000)
# Keyword: well-reasoned tweet           Average sentiment:  0.453   (Std. Dev. = 0.000)
# Keyword: bloviation                    Average sentiment: -0.410   (Std. Dev. = 0.000)
# Keyword: campaign                      Average sentiment: -0.798   (Std. Dev. = 0.000)
# Keyword: soundtrack                    Average sentiment: -0.763   (Std. Dev. = 0.000)
# Keyword: Malcolm Turnbull realise      Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: chance FRFWs                  Average sentiment: -0.691   (Std. Dev. = 0.000)
# Keyword: Dear Peter Dutton             Average sentiment: -0.739   (Std. Dev. = 0.000)
# Keyword: Perfect Storm                 Average sentiment: -0.340   (Std. Dev. = 0.000)
# Keyword: funny feeling                 Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: hero Daniel                   Average sentiment: -0.282   (Std. Dev. = 0.000)
# Keyword: crucial policy overhaul       Average sentiment:  0.879   (Std. Dev. = 0.000)
# Keyword: households                    Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Labor MPs                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Better Muppet                 Average sentiment:  0.652   (Std. Dev. = 0.000)
# Keyword: ’ questions.                  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Fed                           Average sentiment: -0.348   (Std. Dev. = 0.000)
# Keyword: Sharma                        Average sentiment:  0.151   (Std. Dev. = 0.262)
# Keyword: course                        Average sentiment: -0.239   (Std. Dev. = 0.229)
# Keyword: religious beliefs             Average sentiment: -0.823   (Std. Dev. = 0.000)
# Keyword: Pub Test                      Average sentiment: -0.575   (Std. Dev. = 0.000)
# Keyword: lawyer heartless WRECKERS     Average sentiment:  0.684   (Std. Dev. = 0.000)
# Keyword: commentary                    Average sentiment:  0.797   (Std. Dev. = 0.000)
# Keyword: female colleagues liars       Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Worst mistake                 Average sentiment: -0.898   (Std. Dev. = 0.000)
# Keyword: anybody                       Average sentiment:  0.675   (Std. Dev. = 0.000)
# Keyword: tool                          Average sentiment: -0.445   (Std. Dev. = 0.000)
# Keyword: libspill CHEAT&amp            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: climate change                Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Calls proponents zealots      Average sentiment: -0.446   (Std. Dev. = 0.000)
# Keyword: blokes                        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Polliwaffle. The waffle       Average sentiment: -0.321   (Std. Dev. = 0.000)
# Keyword: pages                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: affluent white males          Average sentiment: -0.348   (Std. Dev. = 0.000)
# Keyword: Liberal Party                 Average sentiment: -0.134   (Std. Dev. = 0.438)
# Keyword: reflection                    Average sentiment:  0.681   (Std. Dev. = 0.000)
# Keyword: world                         Average sentiment:  0.526   (Std. Dev. = 0.000)
# Keyword: LIB WOMEN                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: chance                        Average sentiment: -0.480   (Std. Dev. = 0.000)
# Keyword: sanest/smartest               Average sentiment: -0.654   (Std. Dev. = 0.000)
# Keyword: decision                      Average sentiment: -0.150   (Std. Dev. = 0.212)
# Keyword: Joshie                        Average sentiment: -0.251   (Std. Dev. = 0.000)
# Keyword: stated.                       Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: resentment                    Average sentiment: -0.411   (Std. Dev. = 0.000)
# Keyword: secret ballot votes           Average sentiment: -0.753   (Std. Dev. = 0.000)
# Keyword: bright young things           Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Duttons recent antics         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: cactus                        Average sentiment: -0.490   (Std. Dev. = 0.000)
# Keyword: good time                     Average sentiment:  0.822   (Std. Dev. = 0.000)
# Keyword: pair                          Average sentiment:  0.720   (Std. Dev. = 0.000)
# Keyword: Julia                         Average sentiment: -0.524   (Std. Dev. = 0.000)
# Keyword: Angus Taylor                  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: profession                    Average sentiment: -0.431   (Std. Dev. = 0.000)
# Keyword: supporters                    Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Liberal MP Julia              Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Prime Ministership            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Lib voters                    Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: releases Russell Keog         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: WORK                          Average sentiment: -0.591   (Std. Dev. = 0.000)
# Keyword: Lapel Badges                  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: prime ministers               Average sentiment: -0.574   (Std. Dev. = 0.000)
# Keyword: senate                        Average sentiment: -0.493   (Std. Dev. = 0.000)
# Keyword: political careers             Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: merit                         Average sentiment:  0.692   (Std. Dev. = 0.068)
# Keyword: radar                         Average sentiment: -0.175   (Std. Dev. = 0.247)
# Keyword: Mr Turnbull                   Average sentiment: -0.427   (Std. Dev. = 0.000)
# Keyword: ⛪️                            Average sentiment: -0.451   (Std. Dev. = 0.000)
# Keyword: Newstart                      Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: huge achievement              Average sentiment:  0.707   (Std. Dev. = 0.000)
# Keyword: chair                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: senses                        Average sentiment: -0.894   (Std. Dev. = 0.000)
# Keyword: f**k                          Average sentiment: -0.475   (Std. Dev. = 0.000)
# Keyword: Rupert                        Average sentiment: -0.224   (Std. Dev. = 0.447)
# Keyword: Senate Question Time          Average sentiment: -0.458   (Std. Dev. = 0.000)
# Keyword: huge fail                     Average sentiment: -0.843   (Std. Dev. = 0.000)
# Keyword: PS                            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Canberra Times                Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: labor                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: cheeky protest                Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: collective amnesia            Average sentiment: -0.757   (Std. Dev. = 0.000)
# Keyword: answer Simon                  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: bad news                      Average sentiment: -0.662   (Std. Dev. = 0.000)
# Keyword: QT response                   Average sentiment:  0.460   (Std. Dev. = 0.000)
# Keyword: deeper malaise                Average sentiment:  0.540   (Std. Dev. = 0.000)
# Keyword: ideals                        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Wagga by-election results     Average sentiment: -0.312   (Std. Dev. = 0.000)
# Keyword: names                         Average sentiment: -0.373   (Std. Dev. = 0.335)
# Keyword: Polling                       Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: LIBERAL MPS                   Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Koozebane                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: pair Terry                    Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: explosive contempt            Average sentiment: -0.549   (Std. Dev. = 0.000)
# Keyword: 🗣️                            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: voters                        Average sentiment: -0.364   (Std. Dev. = 0.281)
# Keyword: backbencher Craig Kelly       Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: better watch                  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: implode post                  Average sentiment: -0.440   (Std. Dev. = 0.000)
# Keyword: cute deal                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Pastor Morrison               Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: prime minister                Average sentiment:  0.512   (Std. Dev. = 0.000)
# Keyword: final decision                Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: bit                           Average sentiment: -0.501   (Std. Dev. = 0.146)
# Keyword: hokey-pokey                   Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: floor                         Average sentiment: -0.262   (Std. Dev. = 0.262)
# Keyword: Madness                       Average sentiment: -0.735   (Std. Dev. = 0.000)
# Keyword: People                        Average sentiment: -0.160   (Std. Dev. = 0.277)
# Keyword: MP Julia Banks                Average sentiment: -0.360   (Std. Dev. = 0.000)
# Keyword: stupidity                     Average sentiment: -0.651   (Std. Dev. = 0.000)
# Keyword: windfall profits              Average sentiment: -0.724   (Std. Dev. = 0.000)
# Keyword: thuggish supporters Morrison  Average sentiment: -0.627   (Std. Dev. = 0.000)
# Keyword: jbishop                       Average sentiment: -0.523   (Std. Dev. = 0.000)
# Keyword: sexism                        Average sentiment:  0.222   (Std. Dev. = 0.794)
# Keyword: trash                         Average sentiment: -0.633   (Std. Dev. = 0.000)
# Keyword: lobby influence               Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: choice                        Average sentiment: -0.909   (Std. Dev. = 0.000)
# Keyword: dissibillity pension          Average sentiment: -0.877   (Std. Dev. = 0.000)
# Keyword: heart                         Average sentiment:  0.466   (Std. Dev. = 0.000)
# Keyword: Liberal Leader                Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: team                          Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: factor                        Average sentiment: -0.652   (Std. Dev. = 0.000)
# Keyword: cabinet recusal               Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: highly contested title        Average sentiment:  0.526   (Std. Dev. = 0.000)
# Keyword: little frontbench job         Average sentiment: -0.451   (Std. Dev. = 0.000)
# Keyword: J. Edgar Tuber                Average sentiment: -0.547   (Std. Dev. = 0.000)
# Keyword: image                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Ministry                      Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: political Party               Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: political advisors            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: note                          Average sentiment: -0.258   (Std. Dev. = 0.364)
# Keyword: Hastie                        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Leadership spill              Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Selfish politics              Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: religious rights              Average sentiment: -0.401   (Std. Dev. = 0.000)
# Keyword: official tally                Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: asking price                  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Coalition MP Warren           Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: midst                         Average sentiment: -0.224   (Std. Dev. = 0.000)
# Keyword: final Something Morrison      Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Peter Peter                   Average sentiment:  0.622   (Std. Dev. = 0.000)
# Keyword: anniversary                   Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Premises company              Average sentiment:  0.779   (Std. Dev. = 0.000)
# Keyword: Disunited mob                 Average sentiment: -0.488   (Std. Dev. = 0.000)
# Keyword: Lib bullies                   Average sentiment: -0.648   (Std. Dev. = 0.000)
# Keyword: pro-coal agenda               Average sentiment: -0.432   (Std. Dev. = 0.053)
# Keyword: conservative politics         Average sentiment:  0.681   (Std. Dev. = 0.000)
# Keyword: im listening                  Average sentiment:  0.917   (Std. Dev. = 0.000)
# Keyword: looks                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: drought                       Average sentiment: -0.474   (Std. Dev. = 0.000)
# Keyword: male colleagues               Average sentiment: -0.711   (Std. Dev. = 0.000)
# Keyword: Murder murder                 Average sentiment: -0.527   (Std. Dev. = 0.000)
# Keyword: destruction                   Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: preselection night            Average sentiment: -0.343   (Std. Dev. = 0.000)
# Keyword: coal industry                 Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: larger implication            Average sentiment: -0.460   (Std. Dev. = 0.000)
# Keyword: disgraceful,disgusting state  Average sentiment: -0.300   (Std. Dev. = 0.000)
# Keyword: Oct                           Average sentiment: -0.915   (Std. Dev. = 0.000)
# Keyword: pension age                   Average sentiment: -0.289   (Std. Dev. = 0.000)
# Keyword: real estate                   Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: PM                            Average sentiment:  0.219   (Std. Dev. = 0.347)
# Keyword: Parliament.                   Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Lib MP                        Average sentiment: -0.400   (Std. Dev. = 0.000)
# Keyword: recent run                    Average sentiment: -0.610   (Std. Dev. = 0.000)
# Keyword: Undoubtedly                   Average sentiment:  0.790   (Std. Dev. = 0.000)
# Keyword: polls                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Liberal Party drama           Average sentiment: -0.758   (Std. Dev. = 0.000)
# Keyword: president Gary Spence         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: latest article                Average sentiment:  0.828   (Std. Dev. = 0.000)
# Keyword: RKD                           Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: reasoning                     Average sentiment: -0.613   (Std. Dev. = 0.000)
# Keyword: bunch                         Average sentiment:  0.414   (Std. Dev. = 0.586)
# Keyword: bribe                         Average sentiment: -0.917   (Std. Dev. = 0.000)
# Keyword: Spud                          Average sentiment: -0.621   (Std. Dev. = 0.000)
# Keyword: life                          Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: septic bullet                 Average sentiment: -0.564   (Std. Dev. = 0.000)
# Keyword: Devanand Sharma               Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Liberal bully boy             Average sentiment: -0.741   (Std. Dev. = 0.000)
# Keyword: quality guy                   Average sentiment: -0.621   (Std. Dev. = 0.000)
# Keyword: political bullshit            Average sentiment: -0.939   (Std. Dev. = 0.000)
# Keyword: uncivil war                   Average sentiment: -0.374   (Std. Dev. = 0.000)
# Keyword: Liberal Party misogyny        Average sentiment: -0.917   (Std. Dev. = 0.000)
# Keyword: numbers                       Average sentiment: -0.369   (Std. Dev. = 0.323)
# Keyword: internal polling              Average sentiment: -0.365   (Std. Dev. = 0.000)
# Keyword: dollars                       Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: steroids                      Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: smirk                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: vote                          Average sentiment: -0.185   (Std. Dev. = 0.825)
# Keyword: ambition                      Average sentiment:  0.134   (Std. Dev. = 0.189)
# Keyword: self-serving politicians      Average sentiment: -0.604   (Std. Dev. = 0.000)
# Keyword: election ausvotes             Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Bishop hints                  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: accounts                      Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: traditional leadership spill  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: substantial protest vote      Average sentiment: -0.459   (Std. Dev. = 0.000)
# Keyword: currency                      Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: transparency                  Average sentiment:  0.908   (Std. Dev. = 0.000)
# Keyword: accusations                   Average sentiment: -0.402   (Std. Dev. = 0.234)
# Keyword: despicable manner             Average sentiment:  0.667   (Std. Dev. = 0.000)
# Keyword: Prime Muppett SCOMO           Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: came                          Average sentiment:  0.400   (Std. Dev. = 0.000)
# Keyword: swing                         Average sentiment:  0.914   (Std. Dev. = 0.000)
# Keyword: mins                          Average sentiment: -0.848   (Std. Dev. = 0.000)
# Keyword: election                      Average sentiment: -0.145   (Std. Dev. = 0.364)
# Keyword: spill culture                 Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: sacramental wine              Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: utter bollocks                Average sentiment: -0.833   (Std. Dev. = 0.000)
# Keyword: sad stories                   Average sentiment: -0.904   (Std. Dev. = 0.000)
# Keyword: true Liberals                 Average sentiment: -0.241   (Std. Dev. = 0.000)
# Keyword: increasingly nasty tar-pit    Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: funny cigarettes              Average sentiment: -0.691   (Std. Dev. = 0.000)
# Keyword: favour                        Average sentiment: -0.321   (Std. Dev. = 0.000)
# Keyword: Women                         Average sentiment: -0.577   (Std. Dev. = 0.190)
# Keyword: Libs                          Average sentiment: -0.526   (Std. Dev. = 0.257)
# Keyword: party room                    Average sentiment:  0.240   (Std. Dev. = 0.398)
# Keyword: overlords                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Government benches            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Fatman Scoop                  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Baillieu/Napthine/Guy v Newman/Springborg/Nicholls/FrecklingtonAverage sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: media                         Average sentiment: -0.327   (Std. Dev. = 0.462)
# Keyword: political leaders             Average sentiment: -0.479   (Std. Dev. = 0.000)
# Keyword: Warren smoking                Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: possible breaches             Average sentiment: -0.385   (Std. Dev. = 0.000)
# Keyword: Wentworth pick                Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: women’s representation        Average sentiment: -0.682   (Std. Dev. = 0.000)
# Keyword: election Labor                Average sentiment: -0.493   (Std. Dev. = 0.000)
# Keyword: women’s minister              Average sentiment:  0.518   (Std. Dev. = 0.000)
# Keyword: obvious choice                Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: spicy opinions                Average sentiment:  0.853   (Std. Dev. = 0.000)
# Keyword: party room meeting            Average sentiment:  0.063   (Std. Dev. = 1.137)
# Keyword: ratings                       Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: bludgers                      Average sentiment: -0.421   (Std. Dev. = 0.000)
# Keyword: child                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: moment                        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: copyright                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Parliamentary privilege       Average sentiment: -0.497   (Std. Dev. = 0.000)
# Keyword: bloodbath                     Average sentiment: -0.627   (Std. Dev. = 0.139)
# Keyword: Prime Muppet                  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Free Speech                   Average sentiment:  0.313   (Std. Dev. = 0.000)
# Keyword: crimes                        Average sentiment: -0.894   (Std. Dev. = 0.000)
# Keyword: calls                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: gendered bullying             Average sentiment: -0.727   (Std. Dev. = 0.000)
# Keyword: obscure ex-ALP guy            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Malcolm Turnball              Average sentiment:  0.799   (Std. Dev. = 0.000)
# Keyword: standing orders               Average sentiment: -0.211   (Std. Dev. = 0.365)
# Keyword: article Ms Banks              Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: mighty combined forces        Average sentiment:  0.778   (Std. Dev. = 0.000)
# Keyword: long memory                   Average sentiment: -0.674   (Std. Dev. = 0.000)
# Keyword: au pair debarkle              Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: TALK                          Average sentiment: -0.591   (Std. Dev. = 0.000)
# Keyword: Pastoral flock                Average sentiment:  0.809   (Std. Dev. = 0.000)
# Keyword: idea                          Average sentiment:  0.042   (Std. Dev. = 0.282)
# Keyword: Aussie marketing classic      Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Prime Minister                Average sentiment:  0.274   (Std. Dev. = 0.343)
# Keyword: report                        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Pot                           Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: poor excuse                   Average sentiment: -0.920   (Std. Dev. = 0.000)
# Keyword: obstacle                      Average sentiment: -0.771   (Std. Dev. = 0.000)
# Keyword: Labor                         Average sentiment: -0.271   (Std. Dev. = 0.369)
# Keyword: Albo coup                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: damaging ‘gotcha              Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: APH                           Average sentiment: -0.430   (Std. Dev. = 0.000)
# Keyword: foreign interference laws     Average sentiment: -0.770   (Std. Dev. = 0.000)
# Keyword: Nek                           Average sentiment:  0.290   (Std. Dev. = 0.000)
# Keyword: ducks simple question         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: wd                            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: words                         Average sentiment: -0.418   (Std. Dev. = 0.337)
# Keyword: Julia Banks                   Average sentiment: -0.690   (Std. Dev. = 0.228)
# Keyword: Chrissy Pyne                  Average sentiment: -0.576   (Std. Dev. = 0.000)
# Keyword: Yeah                          Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Dave Smith                    Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: important message             Average sentiment:  0.524   (Std. Dev. = 0.000)
# Keyword: ticker                        Average sentiment:  0.466   (Std. Dev. = 0.000)
# Keyword: rest                          Average sentiment: -0.520   (Std. Dev. = 0.000)
# Keyword: Footy                         Average sentiment: -0.757   (Std. Dev. = 0.000)
# Keyword: Opposition                    Average sentiment: -0.626   (Std. Dev. = 0.000)
# Keyword: largest by-election swing     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Shorten                       Average sentiment:  0.085   (Std. Dev. = 0.546)
# Keyword: rabbitandcoffee               Average sentiment: -0.542   (Std. Dev. = 0.000)
# Keyword: assertions                    Average sentiment: -0.741   (Std. Dev. = 0.000)
# Keyword: Catherine King                Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: views                         Average sentiment:  0.763   (Std. Dev. = 0.000)
# Keyword: Correct Aidan                 Average sentiment:  0.831   (Std. Dev. = 0.000)
# Keyword: ATM -automatic teller         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: rise                          Average sentiment:  0.926   (Std. Dev. = 0.000)
# Keyword: resigns                       Average sentiment: -0.878   (Std. Dev. = 0.000)
# Keyword: Facebook                      Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: PMs                           Average sentiment: -0.312   (Std. Dev. = 0.290)
# Keyword: Duttons                       Average sentiment: -0.521   (Std. Dev. = 0.000)
# Keyword: backstabber                   Average sentiment: -0.548   (Std. Dev. = 0.000)
# Keyword: leader                        Average sentiment: -0.191   (Std. Dev. = 0.383)
# Keyword: Dawe                          Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: mortal political souls        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Secret footage                Average sentiment:  0.974   (Std. Dev. = 0.000)
# Keyword: Funny                         Average sentiment: -0.491   (Std. Dev. = 0.000)
# Keyword: coverage                      Average sentiment: -0.227   (Std. Dev. = 0.000)
# Keyword: Morrison                      Average sentiment: -0.190   (Std. Dev. = 0.459)
# Keyword: ScoMo                         Average sentiment:  0.189   (Std. Dev. = 0.305)
# Keyword: election 🤷🏻‍♀️                Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Liberal MPs                   Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Trevor Ruthenberg             Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: ++ n/a                        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: videos                        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: pre-Bjelke Qld copper         Average sentiment:  0.902   (Std. Dev. = 0.000)
# Keyword: vulnerable people             Average sentiment:  0.436   (Std. Dev. = 0.000)
# Keyword: covert control                Average sentiment:  0.387   (Std. Dev. = 0.000)
# Keyword: something.                    Average sentiment: -0.899   (Std. Dev. = 0.000)
# Keyword: vile anti-labor tirade        Average sentiment: -0.848   (Std. Dev. = 0.000)
# Keyword: synonyms                      Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: IMO Labor                     Average sentiment: -0.819   (Std. Dev. = 0.000)
# Keyword: Wagga Wagga byelection        Average sentiment: -0.412   (Std. Dev. = 0.000)
# Keyword: big fuck                      Average sentiment: -0.741   (Std. Dev. = 0.000)
# Keyword: disgust                       Average sentiment:  0.627   (Std. Dev. = 0.000)
# Keyword: vow                           Average sentiment: -0.404   (Std. Dev. = 0.000)
# Keyword: right                         Average sentiment:  0.105   (Std. Dev. = 0.657)
# Keyword: Zoe                           Average sentiment:  0.803   (Std. Dev. = 0.185)
# Keyword: Ohh                           Average sentiment: -0.233   (Std. Dev. = 0.000)
# Keyword: impending Royal Commision     Average sentiment: -0.832   (Std. Dev. = 0.000)
# ...
# Keyword: propaganda                    Average sentiment: -0.633   (Std. Dev. = 0.000)
# Keyword: amnesiacs                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Labspill Series               Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: child care centres            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: ongoing delusion              Average sentiment: -0.402   (Std. Dev. = 0.000)
# Keyword: Australia                     Average sentiment:  0.193   (Std. Dev. = 0.432)
# Keyword: National MPs                  Average sentiment:  0.642   (Std. Dev. = 0.000)
# Keyword: Hey Rocky                     Average sentiment:  0.230   (Std. Dev. = 0.000)
# Keyword: Puppet Master                 Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Turnbull Govt                 Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: MP                            Average sentiment: -0.335   (Std. Dev. = 0.299)
# Keyword: unhappy face                  Average sentiment: -0.472   (Std. Dev. = 0.000)
# Keyword: aka political capital         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Shots                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Turnbull’s fault              Average sentiment: -0.561   (Std. Dev. = 0.000)
# Keyword: Australian Leadership Spills  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: efficiency                    Average sentiment:  0.522   (Std. Dev. = 0.000)
# Keyword: Yep.                          Average sentiment: -0.476   (Std. Dev. = 0.000)
# Keyword: SG                            Average sentiment: -0.229   (Std. Dev. = 0.324)
# Keyword: Cormann                       Average sentiment:  0.311   (Std. Dev. = 0.000)
# Keyword: best place                    Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: word                          Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: leadership change             Average sentiment: -0.680   (Std. Dev. = 0.000)
# Keyword: Herald Sun                    Average sentiment:  0.587   (Std. Dev. = 0.000)
# Keyword: summer break                  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Coalition Corruption          Average sentiment: -0.796   (Std. Dev. = 0.000)
# Keyword: instability                   Average sentiment: -0.376   (Std. Dev. = 0.531)
# Keyword: State Governments             Average sentiment:  0.492   (Std. Dev. = 0.000)
# Keyword: climate friendly equipment.   Average sentiment:  0.762   (Std. Dev. = 0.000)
# Keyword: Scott Morrison PM             Average sentiment: -0.442   (Std. Dev. = 0.000)
# Keyword: Morrison Govt                 Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: political commentary          Average sentiment:  0.270   (Std. Dev. = 0.000)
# Keyword: song                          Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: video                         Average sentiment:  0.377   (Std. Dev. = 0.000)
# Keyword: libspill mess                 Average sentiment: -0.619   (Std. Dev. = 0.000)
# Keyword: Liberal NSW Gov't             Average sentiment: -0.843   (Std. Dev. = 0.000)
# Keyword: dysfunctional Liberal MPs     Average sentiment: -0.560   (Std. Dev. = 0.000)
# Keyword: Australia’s democracy         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Liberal Party meeting         Average sentiment: -0.459   (Std. Dev. = 0.000)
# Keyword: blind eye                     Average sentiment: -0.689   (Std. Dev. = 0.000)
# Keyword: fortunate inheritor           Average sentiment:  0.293   (Std. Dev. = 0.000)
# Keyword: Tony Wright                   Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Bullying Dutton               Average sentiment: -0.689   (Std. Dev. = 0.000)
# Keyword: rancour                       Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: lawn                          Average sentiment: -0.499   (Std. Dev. = 0.000)
# Keyword: outrageous lie                Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Mathias                       Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: PURE CHAOS                    Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: abortion reform supporters    Average sentiment:  0.275   (Std. Dev. = 0.000)
# Keyword: irrefutable logic             Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: pledge                        Average sentiment:  0.884   (Std. Dev. = 0.000)
# Keyword: illegal behaviour             Average sentiment: -0.501   (Std. Dev. = 0.000)
# Keyword: *grabs                        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: House                         Average sentiment: -0.349   (Std. Dev. = 0.494)
# Keyword: little/no tax                 Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: civil war                     Average sentiment: -0.500   (Std. Dev. = 0.000)
# Keyword: country atm.                  Average sentiment: -0.740   (Std. Dev. = 0.000)
# Keyword: Robert Menzies                Average sentiment: -0.758   (Std. Dev. = 0.000)
# Keyword: good                          Average sentiment: -0.584   (Std. Dev. = 0.000)
# Keyword: stunning interview            Average sentiment: -0.678   (Std. Dev. = 0.000)
# Keyword: Brisbane representatives      Average sentiment: -0.786   (Std. Dev. = 0.000)
# Keyword: da house                      Average sentiment:  0.871   (Std. Dev. = 0.000)
# Keyword: brains                        Average sentiment: -0.315   (Std. Dev. = 0.000)
# Keyword: excellently paid jobs         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: SloMo Morrison                Average sentiment: -0.637   (Std. Dev. = 0.000)
# Keyword: Skeksis Emperor               Average sentiment: -0.738   (Std. Dev. = 0.000)
# Keyword: innocent bystander            Average sentiment:  0.605   (Std. Dev. = 0.000)
# Keyword: Dissension                    Average sentiment: -0.449   (Std. Dev. = 0.000)
# Keyword: degrees                       Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Peter Dutton                  Average sentiment: -0.080   (Std. Dev. = 0.325)
# Keyword: information                   Average sentiment: -0.337   (Std. Dev. = 0.000)
# Keyword: ongoing tragedy               Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: bigotry                       Average sentiment: -0.836   (Std. Dev. = 0.000)
# Keyword: public pressure               Average sentiment: -0.763   (Std. Dev. = 0.000)
# Keyword: economic genius               Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: politicians mouth             Average sentiment: -0.321   (Std. Dev. = 0.000)
# Keyword: staffer Richard Dowdy         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: new strategies                Average sentiment: -0.437   (Std. Dev. = 0.000)
# Keyword: twitter account               Average sentiment:  0.642   (Std. Dev. = 0.000)
# Keyword: unpacking                     Average sentiment:  0.902   (Std. Dev. = 0.000)
# Keyword: cabinet records               Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Paris agreement               Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: decency                       Average sentiment:  0.778   (Std. Dev. = 0.000)
# Keyword: Vets                          Average sentiment: -0.368   (Std. Dev. = 0.000)
# Keyword: ok.                           Average sentiment: -0.559   (Std. Dev. = 0.000)
# Keyword: producers                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: boss                          Average sentiment: -0.766   (Std. Dev. = 0.000)
# Keyword: pubs                          Average sentiment: -0.360   (Std. Dev. = 0.000)
# Keyword: liar                          Average sentiment: -0.709   (Std. Dev. = 0.080)
# Keyword: attitude                      Average sentiment: -0.742   (Std. Dev. = 0.000)
# Keyword: lapel pins                    Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: election campaign             Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Village Idiot Abbott          Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Libs tumble                   Average sentiment: -0.520   (Std. Dev. = 0.000)
# Keyword: mouthing empty platitudes     Average sentiment: -0.796   (Std. Dev. = 0.000)
# Keyword: hand                          Average sentiment:  0.002   (Std. Dev. = 0.086)
# Keyword: tock SloMo                    Average sentiment:  0.517   (Std. Dev. = 0.000)
# Keyword: real disgrace                 Average sentiment: -0.441   (Std. Dev. = 0.000)
# Keyword: God                           Average sentiment: -0.133   (Std. Dev. = 0.266)
# Keyword: favorite shopping bag         Average sentiment:  0.910   (Std. Dev. = 0.000)
# Keyword: Internal Investigation        Average sentiment: -0.692   (Std. Dev. = 0.000)
# Keyword: f-cking tonight 😏😘            Average sentiment:  0.497   (Std. Dev. = 0.000)
# Keyword: Moderates                     Average sentiment: -0.413   (Std. Dev. = 0.584)
# Keyword: damage-control talking point  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: peter dutton                  Average sentiment: -0.714   (Std. Dev. = 0.000)
# Keyword: Abbott camp                   Average sentiment: -0.553   (Std. Dev. = 0.000)
# Keyword: MPs                           Average sentiment: -0.382   (Std. Dev. = 0.291)
# Keyword: Dear world                    Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: toilet                        Average sentiment: -0.710   (Std. Dev. = 0.000)
# Keyword: Cronulla Sharks               Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: classic zinger                Average sentiment:  0.870   (Std. Dev. = 0.000)
# Keyword: inanimate object              Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Christmas calendar            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: electoral office              Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: support ❤️                    Average sentiment: -0.241   (Std. Dev. = 0.000)
# Keyword: Peter                         Average sentiment:  0.113   (Std. Dev. = 0.160)
# Keyword: sook                          Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: big pants                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: didnt                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: power                         Average sentiment:  0.179   (Std. Dev. = 0.254)
# Keyword: particular past               Average sentiment: -0.489   (Std. Dev. = 0.000)
# Keyword: tape                          Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: PVO                           Average sentiment: -0.193   (Std. Dev. = 0.273)
# Keyword: house girls                   Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: LIARS                         Average sentiment: -0.847   (Std. Dev. = 0.000)
# Keyword: developments                  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Reports                       Average sentiment: -0.618   (Std. Dev. = 0.000)
# Keyword: Australian parliament         Average sentiment: -0.585   (Std. Dev. = 0.000)
# Keyword: good thing                    Average sentiment:  0.128   (Std. Dev. = 0.920)
# Keyword: suggestions                   Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: sacked former head            Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Bullies                       Average sentiment: -0.678   (Std. Dev. = 0.000)
# Keyword: recent member                 Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: voter                         Average sentiment: -0.437   (Std. Dev. = 0.087)
# Keyword: Anonymous Liberal             Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Nice                          Average sentiment:  0.879   (Std. Dev. = 0.000)
# Keyword: silence re bullying           Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: criminals                     Average sentiment: -0.412   (Std. Dev. = 0.000)
# Keyword: undermines                    Average sentiment: -0.491   (Std. Dev. = 0.000)
# Keyword: broadcasts                    Average sentiment: -0.488   (Std. Dev. = 0.000)
# Keyword: scomofo                       Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: wish                          Average sentiment: -0.794   (Std. Dev. = 0.000)
# Keyword: Dutch Reagan                  Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Queensland LNP fallout        Average sentiment: -0.508   (Std. Dev. = 0.028)
# Keyword: leadership question           Average sentiment: -0.458   (Std. Dev. = 0.000)
# Keyword: right spot                    Average sentiment:  0.902   (Std. Dev. = 0.000)
# Keyword: Coalition voters              Average sentiment: -0.366   (Std. Dev. = 0.000)
# Keyword: New Daily                     Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Kate Jenkins                  Average sentiment: -0.836   (Std. Dev. = 0.000)
# Keyword: members                       Average sentiment: -0.078   (Std. Dev. = 0.134)
# Keyword: Abbott cohort                 Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Libspill Series               Average sentiment: -0.356   (Std. Dev. = 0.000)
# Keyword: Knock Knock                   Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Entsch                        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Scomo cabal                   Average sentiment: -0.819   (Std. Dev. = 0.000)
# Keyword: Female MPs                    Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: stacks                        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: clean energy                  Average sentiment:  0.614   (Std. Dev. = 0.000)
# Keyword: hip hop track                 Average sentiment: -0.609   (Std. Dev. = 0.000)
# Keyword: ewlink                        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: predecessor                   Average sentiment: -0.165   (Std. Dev. = 0.233)
# Keyword: earliest backers              Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Refer                         Average sentiment: -0.428   (Std. Dev. = 0.000)
# Keyword: Energy Prices                 Average sentiment: -0.306   (Std. Dev. = 0.000)
# Keyword: replay                        Average sentiment: -0.377   (Std. Dev. = 0.000)
# Keyword: rules                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Dutti                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: need                          Average sentiment: -0.753   (Std. Dev. = 0.032)
# Keyword: Bullying                      Average sentiment: -0.796   (Std. Dev. = 0.147)
# Keyword: coal                          Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: fabulous diversion/distractionAverage sentiment:  0.488   (Std. Dev. = 0.000)
# Keyword: subsequent state              Average sentiment: -0.302   (Std. Dev. = 0.000)
# Keyword: point scoring                 Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: circus                        Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: different problem             Average sentiment: -0.372   (Std. Dev. = 0.000)
# Keyword: PM Twitter title              Average sentiment: -0.471   (Std. Dev. = 0.000)
# Keyword: private word                  Average sentiment: -0.806   (Std. Dev. = 0.000)
# Keyword: tapes                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Devine intervention           Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: documentary version           Average sentiment:  0.566   (Std. Dev. = 0.000)
# Keyword: my💰it                         Average sentiment:  0.000   (Std. Dev. = 0.000)
# Keyword: Labor/Greens vote             Average sentiment: -0.813   (Std. Dev. = 0.000)
# Keyword: corruption                    Average sentiment: -0.567   (Std. Dev. = 0.000)

# %% [markdown]
# Write our analyses out to disk, so they can be used in the report:

# %%
report_analyses = {
    'sentiment': sentiment_anaylsis,
    'emotion': emotion_analysis,
    'category': category_analysis,
    'keyword': keyword_analysis,
    'entity': entity_analysis,
}

# %%
report_analysis_filename = f"cached_report_analysis_{hashtag}.pkl"

with open(report_analysis_filename, 'wb') as f:
    pickle.dump(report_analyses, f)

# %% [markdown]
# END

# %% [markdown]
# [Return to Contents](#Topic-1:-Text-Analysis)
